# %% [markdown]
# **LAB 3: Ranking**
#
# Harrison Lian U196989
#
# Hugo Da Silva U191838
#
# Brayan González U172820

# %% [markdown]
# **IMPORTS**

# %%
import nltk
nltk.download('stopwords')
from collections import defaultdict
from array import array
from nltk.stem import PorterStemmer
from nltk.corpus import stopwords
import math
import numpy as np
import collections
from numpy import linalg as la
import json
import re
import string
# Out:
# [nltk_data] Error loading stopwords: <urlopen error [Errno 11001]
# [nltk_data]     getaddrinfo failed>

# %% [markdown]
# **AUX FUNCTIONS**

# %%
def pretty_print_tweet(tweet):
    print(
    """id: {}
    username: {}
    text: {}
    date: {}
    hashtags: {}
    likes: {}
    retweets: {}
    url: {}\n""".format(tweet['id'], tweet['username'], tweet['full_text'], tweet['date'], tweet['hashtags'], tweet['likes'],
                        tweet['retweets'], tweet['url']))

# %% [markdown]
# # **LOAD DATA AND CLEAN UP**

# %%
path = 'dataset_tweets_WHO.txt'

#convert the text to json
with open(path) as f:
    tweets_json = json.load(f)

# %%
print(json.dumps(tweets_json['50'], indent=4, sort_keys=True))
# Out:
# {
#     "contributors": null,
#     "coordinates": null,
#     "created_at": "Mon Oct 11 04:43:20 +0000 2021",
#     "display_text_range": [
#         0,
#         140
#     ],
#     "entities": {
#         "hashtags": [],
#         "symbols": [],
#         "urls": [],
#         "user_mentions": [
#             {
#                 "id": 3794682452,
#                 "id_str": "3794682452",
#                 "indices": [
#                     3,
#                     11
#                 ],
#                 "name": "World Health Organization (WHO) Western Pacific",
#                 "screen_name": "WHOWPRO"
#             }
#         ]
#     },
#     "favorite_count": 0,
#     "favorited": false,
#     "full_text": "RT @WHOWPRO: \u201cMy patients are no different to my grandmother and grandfather.\u201d \n\nLoyal to their oath, health workers like Dr Gantsengel Pur\u2026",
#     "geo": null,
#     "id": 1447422540335484932,
#     "id_str": "1447422540335484932",
#     "in_reply_to_screen_name": null,
#     "in_reply_to_status_id": null,
#     "in_reply_to_status_id_str": null,
#     "in_reply_to_user_id": null,
#     "in_reply_to_user_id_str": null,
#     "is_quote_status": false,
#     "lang": "en",
#     "place": null,
#     "retweet_count": 30,
#     "retweeted": false,
#     "retweeted_status": {
#         "contributors": null,
#         "coordinates": null,
#         "created_at": "Sun Oct 10 14:00:00 +0000 2021",
#         "display_text_range": [
#             0,
#             274
#         ],
#         "entities": {
#             "hashtags": [
#                 {
#                     "indices": [
#                         195,
#                         203
#                     ],
#                     "text": "COVID19"
#                 },
#                 {
#                     "indices": [
#                         260,
#                         273
#                     ],
#                     "text": "MentalHealth"
#                 }
#             ],
#             "media": [
#                 {
#                     "display_url": "pic.twitter.com/LCUgSGx0u8",
#                     "expanded_url": "https://twitter.com/WHOWPRO/status/1447200245549514758/video/1",
#                     "id": 1396722733136846849,
#                     "id_str": "1396722733136846849",
#                     "indices": [
#                         275,
#                         298
#                     ],
#                     "media_url": "http://pbs.twimg.com/media/E2IqcGcUcAQhwnN.jpg",
#                     "media_url_https": "https://pbs.twimg.com/media/E2IqcGcUcAQhwnN.jpg",
#                     "sizes": {
#                         "large": {
#                             "h": 270,
#                             "resize": "fit",
#                             "w": 480
#                         },
#                         "medium": {
#                             "h": 270,
#                             "resize": "fit",
#                             "w": 480
#                         },
#                         "small": {
#                             "h": 270,
#                             "resize": "fit",
#                             "w": 480
#                         },
#                         "thumb": {
#                             "h": 150,
#                             "resize": "crop",
#                             "w": 150
#                         }
#                     },
#                     "type": "photo",
#                     "url": "https://t.co/LCUgSGx0u8"
#                 }
#             ],
#             "symbols": [],
#             "urls": [],
#             "user_mentions": []
#         },
#         "extended_entities": {
#             "media": [
#                 {
#                     "additional_media_info": {
#                         "call_to_actions": {
#                             "visit_site": {
#                                 "url": "https://www.who.int/mongolia"
#                             }
#                         },
#                         "description": "",
#                         "embeddable": true,
#                         "monetizable": false,
#                         "title": "Let us #SupportHealthCareWorkers on #WorldMentalHealthDay."
#                     },
#                     "display_url": "pic.twitter.com/LCUgSGx0u8",
#                     "expanded_url": "https://twitter.com/WHOWPRO/status/1447200245549514758/video/1",
#                     "id": 1396722733136846849,
#                     "id_str": "1396722733136846849",
#                     "indices": [
#                         275,
#                         298
#                     ],
#                     "media_url": "http://pbs.twimg.com/media/E2IqcGcUcAQhwnN.jpg",
#                     "media_url_https": "https://pbs.twimg.com/media/E2IqcGcUcAQhwnN.jpg",
#                     "sizes": {
#                         "large": {
#                             "h": 270,
#                             "resize": "fit",
#                             "w": 480
#                         },
#                         "medium": {
#                             "h": 270,
#                             "resize": "fit",
#                             "w": 480
#                         },
#                         "small": {
#                             "h": 270,
#                             "resize": "fit",
#                             "w": 480
#                         },
#                         "thumb": {
#                             "h": 150,
#                             "resize": "crop",
#                             "w": 150
#                         }
#                     },
#                     "type": "video",
#                     "url": "https://t.co/LCUgSGx0u8",
#                     "video_info": {
#                         "aspect_ratio": [
#                             16,
#                             9
#                         ],
#                         "duration_millis": 175000,
#                         "variants": [
#                             {
#                                 "bitrate": 2176000,
#                                 "content_type": "video/mp4",
#                                 "url": "https://video.twimg.com/amplify_video/1396722733136846849/vid/1280x720/RJvJVJZbErkaPtev.mp4?tag=14"
#                             },
#                             {
#                                 "content_type": "application/x-mpegURL",
#                                 "url": "https://video.twimg.com/amplify_video/1396722733136846849/pl/davAgaTXvo8mSYRa.m3u8?tag=14"
#                             },
#                             {
#                                 "bitrate": 832000,
#                                 "content_type": "video/mp4",
#                                 "url": "https://video.twimg.com/amplify_video/1396722733136846849/vid/640x360/ABczbVfdO0SUm8At.mp4?tag=14"
#                             },
#                             {
#                                 "bitrate": 288000,
#                                 "content_type": "video/mp4",
#                                 "url": "https://video.twimg.com/amplify_video/1396722733136846849/vid/480x270/CtFCaEeSa2TPEmH-.mp4?tag=14"
#                             }
#                         ]
#                     }
#                 }
#             ]
#         },
#         "favorite_count": 97,
#         "favorited": false,
#         "full_text": "\u201cMy patients are no different to my grandmother and grandfather.\u201d \n\nLoyal to their oath, health workers like Dr Gantsengel Purev of \ud83c\uddf2\ud83c\uddf3 have worked day and night to protect and save patients from #COVID19 despite their own struggles and the impact on their own #MentalHealth. https://t.co/LCUgSGx0u8",
#         "geo": null,
#         "id": 1447200245549514758,
#         "id_str": "1447200245549514758",
#         "in_reply_to_screen_name": null,
#         "in_reply_to_status_id": null,
#         "in_reply_to_status_id_str": null,
#         "in_reply_to_user_id": null,
#         "in_reply_to_user_id_str": null,
#         "is_quote_status": false,
#         "lang": "en",
#         "place": null,
#         "possibly_sensitive": false,
#         "retweet_count": 30,
#         "retweeted": false,
#         "source": "<a href=\"https://studio.twitter.com\" rel=\"nofollow\">Twitter Media Studio</a>",
#         "truncated": false,
#         "user": {
#             "contributors_enabled": false,
#             "created_at": "Mon Oct 05 18:08:31 +0000 2015",
#             "default_profile": false,
#             "default_profile_image": false,
#             "description": "World Health Organization @WHO in the Western #Pacific Region, \ud83c\udfe0 to 1.9B in #Asia & #Oceania. See new tweets for updated #COVID19 advice. \u27a1\ufe0f RD @takeshi_kasai",
#             "entities": {
#                 "description": {
#                     "urls": []
#                 },
#                 "url": {
#                     "urls": [
#                         {
#                             "display_url": "who.int/westernpacific",
#                             "expanded_url": "http://www.who.int/westernpacific",
#                             "indices": [
#                                 0,
#                                 23
#                             ],
#                             "url": "https://t.co/EblVamM8WW"
#                         }
#                     ]
#                 }
#             },
#             "favourites_count": 6152,
#             "follow_request_sent": false,
#             "followers_count": 219413,
#             "following": false,
#             "friends_count": 1229,
#             "geo_enabled": true,
#             "has_extended_profile": true,
#             "id": 3794682452,
#             "id_str": "3794682452",
#             "is_translation_enabled": false,
#             "is_translator": false,
#             "lang": null,
#             "listed_count": 668,
#             "location": "Manila, Philippines",
#             "name": "World Health Organization (WHO) Western Pacific",
#             "notifications": false,
#             "profile_background_color": "000000",
#             "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#             "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#             "profile_background_tile": false,
#             "profile_banner_url": "https://pbs.twimg.com/profile_banners/3794682452/1616740141",
#             "profile_image_url": "http://pbs.twimg.com/profile_images/899826905532125184/yPM5mxkX_normal.jpg",
#             "profile_image_url_https": "https://pbs.twimg.com/profile_images/899826905532125184/yPM5mxkX_normal.jpg",
#             "profile_link_color": "3B94D9",
#             "profile_sidebar_border_color": "000000",
#             "profile_sidebar_fill_color": "000000",
#             "profile_text_color": "000000",
#             "profile_use_background_image": false,
#             "protected": false,
#             "screen_name": "WHOWPRO",
#             "statuses_count": 10596,
#             "time_zone": null,
#             "translator_type": "none",
#             "url": "https://t.co/EblVamM8WW",
#             "utc_offset": null,
#             "verified": true,
#             "withheld_in_countries": []
#         }
#     },
#     "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>",
#     "truncated": false,
#     "user": {
#         "contributors_enabled": false,
#         "created_at": "Wed Apr 23 19:56:27 +0000 2008",
#         "default_profile": false,
#         "default_profile_image": false,
#         "description": "We are the #UnitedNations\u2019 health agency - #HealthForAll.\n\u25b6\ufe0f Always check our latest tweets on #COVID19 for updated advice/information.",
#         "entities": {
#             "description": {
#                 "urls": []
#             },
#             "url": {
#                 "urls": [
#                     {
#                         "display_url": "who.int",
#                         "expanded_url": "http://www.who.int",
#                         "indices": [
#                             0,
#                             23
#                         ],
#                         "url": "https://t.co/wVulKuROWG"
#                     }
#                 ]
#             }
#         },
#         "favourites_count": 11879,
#         "follow_request_sent": false,
#         "followers_count": 9963586,
#         "following": false,
#         "friends_count": 1743,
#         "geo_enabled": true,
#         "has_extended_profile": true,
#         "id": 14499829,
#         "id_str": "14499829",
#         "is_translation_enabled": false,
#         "is_translator": false,
#         "lang": null,
#         "listed_count": 34215,
#         "location": "Geneva, Switzerland",
#         "name": "World Health Organization (WHO)",
#         "notifications": false,
#         "profile_background_color": "D0ECF8",
#         "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#         "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#         "profile_background_tile": true,
#         "profile_banner_url": "https://pbs.twimg.com/profile_banners/14499829/1610970935",
#         "profile_image_url": "http://pbs.twimg.com/profile_images/875476478988886016/_l61qZdR_normal.jpg",
#         "profile_image_url_https": "https://pbs.twimg.com/profile_images/875476478988886016/_l61qZdR_normal.jpg",
#         "profile_link_color": "0396DB",
#         "profile_sidebar_border_color": "8C8C8C",
#         "profile_sidebar_fill_color": "D9D9D9",
#         "profile_text_color": "000000",
#         "profile_use_background_image": true,
#         "protected": false,
#         "screen_name": "WHO",
#         "statuses_count": 64983,
#         "time_zone": null,
#         "translator_type": "regular",
#         "url": "https://t.co/wVulKuROWG",
#         "utc_offset": null,
#         "verified": true,
#         "withheld_in_countries": []
#     }
# }

# %%
def remove_punct(line):
    """
    Helper function to remove punctuation EXCEPT for '#''
    
    Arugment:
    line -- string of text
    
    Returns:
    line -- string of text without punctuation
    """
    return line.translate(str.maketrans('', '', string.punctuation.replace('#', '')))

def build_terms(line):
    """
    Preprocess the Tweet text by removing stop words, emojis, and punctuation and
    stemming, transforming to lowercase and returning the tokens of the text.
    
    Argument:
    line -- string (text) to be preprocessed
    
    Returns:
    line -- a list of tokens corresponding to the input text after the preprocessing
    """

    stemmer = PorterStemmer()
    stop_words = set(stopwords.words("english"))
    
    # transform to lowercase 
    line =  line.lower() 
    
    # remove non-ASCII terms like emojis and symbols
    line = "".join(c for c in line if c in string.printable) 
    
    # remove punctuation EXCEPT for hashtags (see remove_punct())
    line = remove_punct(line)
    
    # tokenize the text to get a list of terms
    line = line.split() 
    
    # remove html tags, blank spaces like '', and urls
    line = [word for word in line if not (re.match("^qampa$" , word) or re.match("^amp$" , word) or re.match("^http" , word)) 
    and word] 
    
    # remove standalone numbers e.x. '19' but not the 19 from 'covid19'
    line = [word for word in line if not word.isnumeric()]
    
    # add standalone word as token too if it has number e.x. 'covid19' gets tokenized as 'covid19' and 'covid'
    line = line + [word.rstrip(string.digits) for word in line if sum([c.isdigit() for c in word]) != 0]
    
    # remove stopwords
    line = [word for word in line if word not in stop_words] 
    
    # perform stemming
    line = [stemmer.stem(word) for word in line]
    
    # add unhashtagged word if it's hashtag is present 
    # e.x. if #covid is present, we also add covid as a token
    line = line + [word.replace('#', '') for word in line if word[0] == '#' ] 
    
    return line

# %%
# tweet_dict is our output data structure that maps Tweet IDs to their text
# note we need to keep the following information
# Tweet | Username | Date | Hashtags | Likes | Retweets | Url

def create_tweets(tweets_json):
    tweet_dict = defaultdict()
    tweets = []

    for key in tweets_json:
        tweet_data = {
            'id': tweets_json[key]['id'],
            'full_text': tweets_json[key]['full_text'],
            'tokens': build_terms(tweets_json[key]['full_text']),
            'username': tweets_json[key]['user']['name'],
            'date': tweets_json[key]['created_at'],
            'hashtags': [key['text'] for key in tweets_json[key]['entities']['hashtags']],
            'likes': tweets_json[key]['favorite_count'],
            'retweets': tweets_json[key]['retweet_count'], 
        }

        #sometimes the tweet url doesn't exist
        try:
            tweet_data['url'] = tweets_json[key]['entities']['media'][0]['url']
        except:
            tweet_data['url'] = None
        
        tweets.append(tweet_data)
    return tweets

# %% [markdown]
# # **CREATE INDEXES**

# %%
# create index
def create_index(tweets_json):
    tweets = create_tweets(tweets_json)
    index = defaultdict(list)
    title_index = defaultdict()

    for tweet in tweets:
        title_index[tweet['id']] = tweet
        
        #current page index keeps track of postision of each word in tweet
        #e.x. if our tweet #50 has tokens "covid health world covid", our current_page_index looks like:
        # {covid -> [50, [0, 3]], health -> [50, [1]], world [50, [2]]}
        current_page_index = {}
        for position, word in enumerate(tweet['tokens']):
            
            try:
                # if the term is already in the index for the current page (current_page_index)
                # append the position to the corresponding list
                current_page_index[word][1].append(position)  
            except:
                # Add the new term as dict key and initialize the array of positions and add the position
                current_page_index[word]=[tweet['id'], array('I', [position])] #'I' indicates unsigned int (int in Python)
        

        for term_page, posting_page in current_page_index.items():
            index[term_page].append(posting_page)
    
    return index, title_index

# %%
# apply tf-idf
# tweets is a list of tokens
def create_tfidf_index(tweets):
    index = defaultdict(list)
    tf = defaultdict(list)  #term frequencies of terms in documents (documents in the same order as in the main index)
    df = defaultdict(int)  #document frequencies of terms in the corpus
    title_index = defaultdict()
    idf = defaultdict(float)


    for tweet in tweets:
        
        title_index[tweet['id']] = tweet
        current_page_index = {}

        for position, term in enumerate(tweet['tokens']):  ## terms contains page_title + page_text
            try:
                # if the term is already in the dict append the position to the corresponding list
                current_page_index[term][1].append(position)
            except:
                # Add the new term as dict key and initialize the array of positions and add the position
                current_page_index[term]=[tweet['id'], array('I',[position])] #'I' indicates unsigned int (int in Python)

        #normalize term frequencies
        # Compute the denominator to normalize term frequencies (formula 2 above)
        # norm is the same for all terms of a document.
        norm = 0
        for term, posting in current_page_index.items():
            # posting will contain the list of positions for current term in current document. 
            # posting ==> [current_doc, [list of positions]] 
            # you can use it to infer the frequency of current term.
            
            #CHECK THIS!
            norm += len(posting[1]) ** 2
        norm = math.sqrt(norm)

        #calculate the tf(dividing the term frequency by the above computed norm) and df weights
        for term, posting in current_page_index.items():
            # append the tf for current term (tf = term frequency in current doc/norm)
            tf[term].append(np.round(len(posting[1])/norm, 4)) ## SEE formula (1) above
            #increment the document frequency of current term (number of documents containing the current term)
            df[term] += 1 # increment DF for current term

        #merge the current page index with the main index
        for term_page, posting_page in current_page_index.items():
            index[term_page].append(posting_page)

        # Compute IDF following the formula (3) above. HINT: use np.log
        for term in df:
            idf[term] = 1 + np.round(np.log(float(len(tweets)/df[term])), 4)

    return index, tf, df, idf, title_index

# %% [markdown]
# # **RANK TF-IDF + COS SIMILARITY; CUSTOM RANKING + TF-COS SIMILARITY**

# %%
def search_ranking(query, index, mode = 'TF-IDF'):
    """
    output is the list of documents that contain any of the query terms. 
    So, we will get the list of documents for each query term, and take the union of them.
    """
    query = build_terms(query)
    docs = set()
    for term in query:
        try:
            # store in term_docs the ids of the docs that contain "term"                        
            term_docs=[posting[0] for posting in index[term]]
            
            # docs = docs Union term_docs
            docs = docs.union(set(term_docs))
            #docs = set(term_docs)
            #print(docs)
        except:
            #term is not in index
            pass
        

    docs = list(docs)
    if mode == 'TF-IDF':
        ranked_docs, pred_score = rank_documents_tfidf_cos(query, docs, index, idf, tf, title_index)
    elif mode == 'custom':
        ranked_docs, pred_score =rank_documents_custom(query, docs, index, tf, title_index)
    else:
        ranked_docs, pred_score = rank_documents_bm25_custom(query, docs, index, tf, title_index)
    return ranked_docs, pred_score

# %%
def rank_documents_tfidf_cos(terms, docs, index, idf, tf, title_index):
    """
    Perform the ranking of the results of a search based on the tf-idf weights
    
    Argument:
    terms -- list of query terms
    docs -- list of documents, to rank, matching the query
    index -- inverted index data structure
    idf -- inverted document frequencies
    tf -- term frequencies
    title_index -- mapping between page id and page title
    
    Returns:
    Print the list of ranked documents
    """

    # I'm interested only on the element of the docVector corresponding to the query terms 
    # The remaining elements would became 0 when multiplied to the query_vector
    # I call doc_vectors[k] for a nonexistent key k, the key-value pair (k,[0]*len(terms)) will be automatically added to the dictionary
    doc_vectors = defaultdict(lambda: [0] * len(terms)) 
    query_vector = [0] * len(terms)

    # compute the norm for the query tf
    query_terms_count = collections.Counter(terms)  # get the frequency of each term in the query. 
    # Example: collections.Counter(["hello","hello","world"]) --> Counter({'hello': 2, 'world': 1})
    #HINT: use when computing tf for query_vector

    query_norm = la.norm(list(query_terms_count.values()))

    for termIndex, term in enumerate(terms):  #termIndex is the index of the term in the query
        if term not in index:
            continue

        ## Compute tf*idf(normalize TF as done with documents)
        query_vector[termIndex] = query_terms_count[term]/query_norm * idf[term] 

        # Generate doc_vectors for matching docs
        for doc_index, (doc, postings) in enumerate(index[term]):
            # Example of [doc_index, (doc, postings)]
            # 0 (26, array('I', [1, 4, 12, 15, 22, 28, 32, 43, 51, 68, 333, 337]))
            # 1 (33, array('I', [26, 33, 57, 71, 87, 104, 109]))
            # term is in doc 26 in positions 1,4, .....
            # term is in doc 33 in positions 26,33, .....

            #tf[term][0] will contain the tf of the term "term" in the doc 26            
            if doc in docs:
                doc_vectors[doc][termIndex] = tf[term][doc_index] * idf[term]  

    # Calculate the score of each doc 
    # compute the cosine similarity between queyVector and each docVector:
    
    doc_scores=[[np.dot(curDocVec, query_vector) / (np.linalg.norm(curDocVec) * np.linalg.norm(query_vector)), doc] for doc, curDocVec in doc_vectors.items() ]
    doc_scores.sort(reverse=True)
    result_docs = [x[1] for x in doc_scores]
    result_pred_score = [x[0] for x in doc_scores]

    #print document titles instead if document id's
    #result_docs=[ title_index[x] for x in result_docs ]
    if len(result_docs) == 0:
        print("No results found, try again")
        query = input()
        docs = search_ranking(query, index)
    #print ('\n'.join(result_docs), '\n')
    return result_docs, result_pred_score

# %%
def rank_documents_custom(terms, docs, index, tf, title_index):    

    doc_vectors = defaultdict(lambda: [0] * len(terms)) 
    query_vector = [0] * len(terms)

    query_terms_count = collections.Counter(terms)
    #query_norm = la.norm(list(query_terms_count.values()))

    for termIndex, term in enumerate(terms):  #termIndex is the index of the term in the query
        if term not in index:
            continue

        ## Compute tf*idf(normalize TF as done with documents)
        query_vector[termIndex] = query_terms_count[term] #/ query_norm 

        for doc_index, (doc, postings) in enumerate(index[term]):
            #tf[term][0] will contain the tf of the term "term" in the doc 26            
            if doc in docs:
                doc_vectors[doc][termIndex] = tf[term][doc_index] 
    

    # Calculate the score of each doc 
    # compute the cosine similarity between queyVector and each docVector
    # weight the score based on likes and retweets

    doc_scores=[[(np.dot(curDocVec, query_vector) / (np.linalg.norm(curDocVec) * np.linalg.norm(query_vector)))*0.7 + ((int(title_index[doc]['likes']) * 0.4) + int(title_index[doc]['retweets']) * 0.6)*0.3, doc] for doc, curDocVec in doc_vectors.items() ]
    doc_scores.sort(reverse=True)
    result_docs = [x[1] for x in doc_scores]
    result_pred_score = [x[0] for x in doc_scores]



    return result_docs, result_pred_score

# %%
from rank_bm25 import BM25Okapi
def rank_documents_bm25_custom(terms, docs, index, tf, title_index):
    """
    we use external library to calculate the bm25
    all algorithms are in this paper http://www.cs.otago.ac.nz/homepages/andrew/papers/2014-2.pdf
    
    This function, similar to the other ranking functions, calculates the custom bm25 score
    
    Argument:
    terms -- list of query terms
    docs -- list of documents, to rank, matching the query
    index -- inverted index data structure
    idf -- inverted document frequencies
    tf -- term frequencies
    title_index -- mapping between page id and page title
    
    Returns:
    Print the list of ranked documents
    """
    
    
    try:
        tokenized_corpus = [title_index[doc_id]['tokens'] for doc_id in docs]
    except:
        print(docs)
    bm25_model = BM25Okapi(tokenized_corpus)
    
    #bm25_score calculates the bm25 score for each documents, given the query vector 'terms'
    bm25_score = bm25_model.get_scores(terms)
    
    #we will now calculate our custom score
    updated_results = []
    for i in range(len(docs)):
        curr_bm25 = bm25_score[i]
        tweet = docs[i]
        
        #initialize the metrics that we will use to calculate custom score
        #explanations and motivations are in the writeup
        
        #curr_length_hashtag_ratio is 1 + log(len(tweet)/(num of hashtags))
        curr_length_hashtag_ratio = 1
        
        #curr_num_likes is 1 + log(len(likes))
        curr_num_likes = 1
        
        #curr_num_retweets is 1 + log(len(retweets))
        curr_retweets = 1
        
        #multiple try clauses in case we divide by 0 or take the logarithm of 0
        try:
            curr_length_hashtag_ratio = 1 + np.log(len(tweet['tokens'])/len(tweet['hashtags']))
        except:
            pass
        
        try:
            curr_num_likes = 1 + np.log(int(tweet['likes']))
        except:
            pass
        
        try:
            curr_retweets = 1 + np.log(int(tweet['retweets']))
            score = curr_bm25 * curr_length_hashtag_ratio * curr_num_likes * curr_retweets
            updated_results.append(score)
        except:
            pass
        return docs, updated_results

# %%
tweets = create_tweets(tweets_json)
index, tf, df, idf, title_index = create_tfidf_index(tweets)

# %%
print("Insert your query (i.e.: Computer Science):\n")
query = input()
#play around with this function! the third argument is either 'TF-IDF', 'custom', or 'bm25'
ranked_docs, _ = search_ranking(query, index, 'bm25')

top = 20

print("\n======================\nTop {} results out of {} for the searched query:\n".format(top, len(ranked_docs)))
count = 1
#print(ranked_docs[0])
for d_id in ranked_docs[:top]:
    print("rank: {}".format(count))
    #print(d_id)
    #print(title_index)
    pretty_print_tweet(title_index[d_id])
    count += 1
# Out:
# Insert your query (i.e.: Computer Science):
#
# death risk
#
# ======================
# Top 20 results out of 207 for the searched query:
#
# rank: 1
# id: 1444751108040232960
#     username: World Health Organization (WHO)
#     text: Many countries around the 🌎🌍🌏 still face steep increases in #COVID19 cases &amp; deaths.
#
# WHO continues to provide critical support from improving regional #COVID19 vaccine production to delivering medical supplies to the vulnerable.
#
# 👉https://t.co/9hp1lPg1ZY #WHOImpact https://t.co/Xp0ZAEjMbW
#     date: Sun Oct 03 19:48:00 +0000 2021
#     hashtags: ['COVID19', 'COVID19', 'WHOImpact']
#     likes: 122
#     retweets: 49
#     url: https://t.co/Xp0ZAEjMbW
#
# rank: 2
# id: 1443099206017814528
#     username: World Health Organization (WHO)
#     text: Today is #WorldHeartDay ♥️!
#
# Cardiovascular diseases including heart attacks and strokes are the leading cause of death globally, accounting for nearly 1⃣8⃣ million lives lost every year.
#
# Protect your heart 🫀 by choosing a healthy lifestyle 🏃🍊🚭
#
# 👉 https://t.co/afDLfGN0mT https://t.co/eUcahnouvb
#     date: Wed Sep 29 06:23:56 +0000 2021
#     hashtags: ['WorldHeartDay']
#     likes: 1558
#     retweets: 938
#     url: https://t.co/eUcahnouvb
#
# rank: 3
# id: 1443129790979051522
#     username: World Health Organization (WHO)
#     text: Today is #WorldHeartDay 💗
#
# #Hypertension - or elevated blood pressure - is a serious medical condition that significantly increases the risks of ❤, 🧠, kidney &amp; other diseases. It is a major cause of premature death worldwide.
#
# 👉 https://t.co/PEXOASL1Tg https://t.co/L6vriEK1yc
#     date: Wed Sep 29 08:25:28 +0000 2021
#     hashtags: ['WorldHeartDay', 'Hypertension']
#     likes: 229
#     retweets: 107
#     url: https://t.co/L6vriEK1yc
#
# rank: 4
# id: 1445778779939373059
#     username: World Health Organization (WHO)
#     text: @DrTedros "But globally, progress has stalled at an unacceptably high level, with more than 200 million cases and 400 thousand deaths every year. Two-thirds of those deaths are children under five in Africa"-@DrTedros #EndMalaria
#
# https://t.co/5PGWhPf6dt
#     date: Wed Oct 06 15:51:37 +0000 2021
#     hashtags: ['EndMalaria']
#     likes: 132
#     retweets: 38
#     url: None
#
# rank: 5
# id: 1447663774811541508
#     username: World Health Organization (WHO)
#     text: People around the 🌐 breathe unhealthy levels of #AirPollution, largely resulting from burning fossil fuels driving #ClimateChange.
#
# #ClimateAction could reduce the total number of global deaths from air pollution by 80% 👉 https://t.co/43l5mmAwOq https://t.co/Qz5kERdI1x
#     date: Mon Oct 11 20:41:54 +0000 2021
#     hashtags: ['AirPollution', 'ClimateChange', 'ClimateAction']
#     likes: 250
#     retweets: 97
#     url: https://t.co/Qz5kERdI1x
#
# rank: 6
# id: 1445778657004294149
#     username: World Health Organization (WHO)
#     text: @DrTedros "We have made incredible progress in the fight against #malaria in the past 2 decades.
#
# Since 2000, malaria deaths have fallen by more than half, and we have succeeded in eliminating malaria from many parts of the world"-@DrTedros #EndMalaria
#     date: Wed Oct 06 15:51:07 +0000 2021
#     hashtags: ['malaria', 'EndMalaria']
#     likes: 155
#     retweets: 37
#     url: None
#
# rank: 7
# id: 1447115031813017604
#     username: World Health Organization (WHO)
#     text: It's #WorldMentalHealthDay.
#
# DYK: 1️⃣ in 1️⃣0️⃣0️⃣ deaths is by #suicide. For every suicide there are many more people who attempt suicide. A prior suicide attempt is an important risk factor.
# #LetsTalk https://t.co/cugMvd8oHu
#     date: Sun Oct 10 08:21:24 +0000 2021
#     hashtags: ['WorldMentalHealthDay', 'suicide', 'LetsTalk']
#     likes: 298
#     retweets: 142
#     url: https://t.co/cugMvd8oHu
#
# rank: 8
# id: 1445383412932620291
#     username: World Health Organization (WHO)
#     text: Two-thirds of maternal deaths occur in Sub-Saharan Africa 🌍
#
# Countries with the highest-burden need intensified support to strengthen access to high-quality care before, during, and after pregnancy and childbirth
#
# https://t.co/DhTF3jxQB0 https://t.co/kp3mDKrnT3
#     date: Tue Oct 05 13:40:34 +0000 2021
#     hashtags: []
#     likes: 250
#     retweets: 63
#     url: https://t.co/kp3mDKrnT3
#
# rank: 9
# id: 1445350148616380420
#     username: World Health Organization (WHO)
#     text: Tragically, 810 women 👩🧕🏾👩🏼‍🦰 die each day due to complications of pregnancy and childbirth, and the 🌏 is off-track to end preventable maternal deaths.
#
# Today WHO and @UNFPA launch new targets to help countries get back on course.
# https://t.co/DhTF3jxQB0 https://t.co/SF6tVyObKT
#     date: Tue Oct 05 11:28:23 +0000 2021
#     hashtags: []
#     likes: 763
#     retweets: 261
#     url: https://t.co/SF6tVyObKT
#
# rank: 10
# id: 1445783298756595721
#     username: World Health Organization (WHO)
#     text: A child dies from #malaria every two minutes.
# One death is one too many.
#
# 🚨 Today, WHO recommends RTS,S, a groundbreaking malaria vaccine, to reduce child illness &amp; deaths in areas with moderate and high malaria transmission https://t.co/xSk58nTIV1
#
# #VaccinesWork https://t.co/mSECLtRhQs
#     date: Wed Oct 06 16:09:34 +0000 2021
#     hashtags: ['malaria', 'VaccinesWork']
#     likes: 4936
#     retweets: 2795
#     url: https://t.co/mSECLtRhQs
#
# rank: 11
# id: 1443984064441114628
#     username: World Health Organization (WHO)
#     text: It's International Day of Older Persons.
#
# DYK: Among older people, ageism is associated with increased social isolation and loneliness, greater financial insecurity, decreased quality of life and premature death.
#
# #AWorld4AllAges https://t.co/nThXODKD6L
#     date: Fri Oct 01 17:00:03 +0000 2021
#     hashtags: ['AWorld4AllAges']
#     likes: 193
#     retweets: 71
#     url: https://t.co/nThXODKD6L
#
# rank: 12
# id: 1443566593099943940
#     username: World Health Organization (WHO)
#     text: RT @DrTedros: In #Tigray, Ethiopia, over 5 million people face starvation. With #famine comes widespread disease and death. We call for urg…
#     date: Thu Sep 30 13:21:10 +0000 2021
#     hashtags: ['Tigray', 'famine']
#     likes: 0
#     retweets: 2736
#     url: None
#
# rank: 13
# id: 1443137651507335171
#     username: World Health Organization (WHO)
#     text: By 2030, the new roadmap to #DefeatMeningitis aims to:
#
# 🚩 eliminate bacterial meningitis epidemics
# 🚩 reduce cases of vaccine-preventable bacterial meningitis by 50% &amp; deaths by 70%
# 🚩 reduce disability &amp; improve quality of life for meningitis survivors. https://t.co/aKbypExBtg
#     date: Wed Sep 29 08:56:42 +0000 2021
#     hashtags: ['DefeatMeningitis']
#     likes: 123
#     retweets: 41
#     url: https://t.co/aKbypExBtg
#
# rank: 14
# id: 1441102828571750410
#     username: World Health Organization (WHO)
#     text: Unhealthy diets cause 1️⃣1️⃣ million deaths per year.
#
# Here are 6⃣ #FoodSystems actions areas that impact &amp; improve people’s &amp; planetary health 👇
#
# https://t.co/9QvFA16RNw
#     date: Thu Sep 23 18:11:03 +0000 2021
#     hashtags: ['FoodSystems']
#     likes: 118
#     retweets: 39
#     url: None
#
# rank: 15
# id: 1445393931399729166
#     username: World Health Organization (WHO)
#     text: Most maternal deaths are preventable with the right care at the right time. Women must get access to healthcare, and this care must:
#
# ✅ be of high quality.
# ✅ meet the needs of families
# ✅ treat them with dignity and respect.
#
# https://t.co/DhTF3jxQB0 https://t.co/TNqBsiyyfx
#     date: Tue Oct 05 14:22:22 +0000 2021
#     hashtags: []
#     likes: 432
#     retweets: 116
#     url: https://t.co/TNqBsiyyfx
#
# rank: 16
# id: 1440690849042468875
#     username: World Health Organization (WHO)
#     text: In adults 🧕👨, ischaemic heart disease and stroke are the most common causes of premature death attributable to outdoor #AirPollution, and evidence is also emerging of other effects such as #diabetes and neurodegenerative conditions.
#
# 👉 https://t.co/7NnUI54JzT https://t.co/omTN1ABvSl
#     date: Wed Sep 22 14:53:59 +0000 2021
#     hashtags: ['AirPollution', 'diabetes']
#     likes: 318
#     retweets: 105
#     url: https://t.co/omTN1ABvSl
#
# rank: 17
# id: 1440671322602819596
#     username: World Health Organization (WHO)
#     text: Every year, exposure to #AirPollution is estimated to cause 7⃣ million premature deaths and result in the loss of millions more healthy years of life.
#
# 🆕 guidelines recommend air quality levels to protect health and save lives around the 🌎🌍🌏
#
# 👉 https://t.co/7NnUI54JzT https://t.co/C3CaWnVChf
#     date: Wed Sep 22 13:36:24 +0000 2021
#     hashtags: ['AirPollution']
#     likes: 1213
#     retweets: 706
#     url: https://t.co/C3CaWnVChf
#
# rank: 18
# id: 1440667404405669899
#     username: World Health Organization (WHO)
#     text: "There is nothing more essential for life than air.
#
# And yet because of #airpollution, the simple act of breathing contributes to 7 million deaths a year.
#
# Almost everyone around the world is exposed to unhealthy levels of air pollution"-@DrTedros
#     date: Wed Sep 22 13:20:50 +0000 2021
#     hashtags: ['airpollution']
#     likes: 228
#     retweets: 86
#     url: None
#
# rank: 19
# id: 1438884395176312835
#     username: World Health Organization (WHO)
#     text: A large number of work-related deaths occur among:
#
# 🔺 people living in South-East Asia &amp; the Western Pacific 🌏
# 🔺 males
# 🔺 people aged over 54 years.
#
# The WHO/@ILO joint study provides preventive actions to improve &amp; protect #WorkersHealth &amp; safety 👉https://t.co/mEXoBqYt5g https://t.co/8ZuhBlBVt4
#     date: Fri Sep 17 15:15:47 +0000 2021
#     hashtags: ['WorkersHealth']
#     likes: 105
#     retweets: 36
#     url: https://t.co/8ZuhBlBVt4
#
# rank: 20
# id: 1437788443384369162
#     username: World Health Organization (WHO)
#     text: @DrTedros @gavi @CEPIvaccines @UNICEF @_AfricanUnion @JNkengasong @SongweVera @CyrilRamaphosa @UN @afreximbank @GaviSeth @MoetiTshidi @WHOAFRO "Every day, nearly 5,400 babies are stillborn, &amp; more than 800 women &amp; 6,700 newborns die mainly around the time of childbirth. These deaths are mostly avoidable with safe &amp; quality care, delivered by skilled health professionals, supported by a strong health system"-@DrTedros
#     date: Tue Sep 14 14:40:52 +0000 2021
#     hashtags: []
#     likes: 129
#     retweets: 44
#     url: None

# %%
###word2vec
import pandas as pd
from gensim.models import Word2Vec
from gensim.utils import simple_preprocess
from gensim.parsing.preprocessing import preprocess_string
import nltk
#create a word2Vec model
words = [tweet['tokens'] for tweet in tweets]
w2v_model = Word2Vec(sentences = words, size = 100, min_count = 1, window = 10, negative = 15, sg = 0)

# %%
#check size of our w2vector
w2v_model.vector_size
# Out:
# 100

# %%
def avg_vector(model, terms):
    """
    this function averages the vectors that are the word embeddings for a series of terms
    
    Argument:
    model -- our trained w2v model
    terms -- list of tokenized words e.x. ['covid', 'reduct', 'vacc']
    
    Returns:
    np ndarray of the "average" word embedding of our terms
    """
    
    assert(len(terms) > 0)
    result = np.ndarray(shape = (model.vector_size,))
  
    
    for term in terms:
        try:
            curr_vec = model[term]
            result = np.add(curr_vec, result)
        except:
            print(term + " not found")
    return result/len(terms)

# %%
# Now we need to create a w2v representation of each tweet
# output is a dicionary mapping tweet ID to their vector representations
def create_tweet_vecs(model, title_index):
    """ 
    Argument:
    model -- our trained w2v model
    title_index -- mapping between tweet id and tweet contents
    
    Returns:
    Dictionary that maps tweet IDs to their vector representations"""
    result = dict()
    for key in title_index.keys():
        tokens = title_index[key]['tokens']
        if len(tokens) > 0:
            tweet_vec = avg_vector(model, tokens)
            result[key] = tweet_vec
    return result
tweet_vecs = create_tweet_vecs(w2v_model, title_index)
# Out:
# C:\Users\Harrison\anaconda3\lib\site-packages\ipykernel_launcher.py:19: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).

# %%
# compute cosine similarity
def cos_similarity(query, doc):
    """
    Argument:
    query -- w2v representation of query terms
    doc -- w2v representation of terms in the tweet

    
    Returns:
    cosine similarity of the two vectors
    """
    return np.dot(query, doc) / (np.linalg.norm(query) * np.linalg.norm(doc))


# function that prints our top k results, using word2vec and cosine similarity
def rank_top_k(query_vec, tweet_vecs, title_index, k = 20):
    """
    Arguments:
        query_vec -- w2v representation of our query
        tweet_vecs -- dictionary that maps tweet ids to their vector representations
        title_index -- maps tweet ids to their contents
        k -- parameter to control how many tweets to print out
    """
    
    #result maps Tweet ids to their cosine similarity scores with the query
    result = dict()
    
    for key in tweet_vecs.keys():
        result[key] = cos_similarity(query_vec, tweet_vecs[key])
    result = sorted(result.items() ,key=lambda item: item[1], reverse=True)[:k]
    
    rank = 1
    for (id, score) in result:
        print(rank, " score: ", score)
        pretty_print_tweet(title_index[id])
        rank += 1
# Out:
# congrat not found
# 1  score:  0.9999999999963989
# id: 1408028717763416065
#     username: World Health Organization (WHO)
#     text: Today is Day 1 of #SelfCare Month!  💪
#
# Throughout this month we'll be sharing tips to help you protect your health - during the #COVID19 pandemic and beyond  👇
# https://t.co/0U9jroJSCx
#     date: Thu Jun 24 11:46:20 +0000 2021
#     hashtags: ['SelfCare', 'COVID19']
#     likes: 2528
#     retweets: 720
#     url: None
#
# 2  score:  0.9999999999915133
# id: 1408017215190933507
#     username: World Health Organization (WHO)
#     text: The right to health means the right to control one’s health and body – including the sexual and reproductive health rights of women and girls – without interference https://t.co/0xs5xwkoTg
#
# #HealthForAll #StandUp4HumanRights https://t.co/qfh5PQ8S2D
#     date: Thu Jun 24 11:00:38 +0000 2021
#     hashtags: ['HealthForAll', 'StandUp4HumanRights']
#     likes: 287
#     retweets: 96
#     url: https://t.co/qfh5PQ8S2D
#
# 3  score:  0.9999999999873064
# id: 1408027564321484802
#     username: World Health Organization (WHO)
#     text: RT @DrTedros: Very pleased to have spoken with Her Majesty Queen Mathilde of #Belgium about the upcoming 'Impact of violence against childr…
#     date: Thu Jun 24 11:41:45 +0000 2021
#     hashtags: ['Belgium']
#     likes: 0
#     retweets: 67
#     url: None
#
# 4  score:  0.9999999999855348
# id: 1408027482113163265
#     username: World Health Organization (WHO)
#     text: RT @DrTedros: The #COVID19 situation in Africa is worrisome. Both the number of cases &amp; deaths are almost 40% higher than the week before.…
#     date: Thu Jun 24 11:41:26 +0000 2021
#     hashtags: ['COVID19']
#     likes: 0
#     retweets: 545
#     url: None
#
# 5  score:  0.9999999999850466
# id: 1408060159004270604
#     username: World Health Organization (WHO)
#     text: Take time each day for things you enjoy and to stay connected with those you 🤎
#
# ✅ Keep in touch with people you care about
# ✅ Think about what you can do for others
# ✅ Reach out to a trusted person or health worker if you need help
#
# 👉 https://t.co/0U9jroshdX https://t.co/yZpiyHMVgi
#     date: Thu Jun 24 13:51:17 +0000 2021
#     hashtags: []
#     likes: 509
#     retweets: 199
#     url: https://t.co/yZpiyHMVgi
#
# 6  score:  0.9999999999814312
# id: 1408087054634799106
#     username: World Health Organization (WHO)
#     text: LIVE Q&amp;A on #COVID19 variants and vaccines with @doctorsoumya. #AskWHO https://t.co/RFfQvz1kmp
#     date: Thu Jun 24 15:38:09 +0000 2021
#     hashtags: ['COVID19', 'AskWHO']
#     likes: 508
#     retweets: 239
#     url: None
#
# 7  score:  0.9999999999571537
# id: 1408041924460699655
#     username: World Health Organization (WHO)
#     text: Maintaining a healthy lifestyle is vital. This means:
#
# 🍊 Eating healthily
# 🏃‍♀️ Being physically active
# 🚭 Avoiding alcohol and tobacco
# 💤 Getting enough sleep
#
# 👉 https://t.co/0U9jroJSCx
#
# #SelfCare Month
# https://t.co/crF6gAgSQW
#     date: Thu Jun 24 12:38:49 +0000 2021
#     hashtags: ['SelfCare']
#     likes: 484
#     retweets: 208
#     url: https://t.co/crF6gAgSQW
#
# 8  score:  0.9999999999449631
# id: 1408411083749171202
#     username: World Health Organization (WHO)
#     text: New #SelfCare recommendations include:
# ✅ provision of 🤰 self-tests with no prescription
# ✅ Pharmacy access to emergency contraception
# ✅ Self-management of iron &amp; folic acid supplementation
# ✅ Self-monitoring of blood glucose &amp; pressure during 🤰
#
# 👉 https://t.co/dDDfj4PPEm https://t.co/6SjRf6yUBD
#     date: Fri Jun 25 13:05:44 +0000 2021
#     hashtags: ['SelfCare']
#     likes: 159
#     retweets: 28
#     url: https://t.co/6SjRf6yUBD
#
# 9  score:  0.9999999999389482
# id: 1408391491827945479
#     username: World Health Organization (WHO)
#     text: #SelfCare interventions should be complementary to #PrimaryHealthCare and not a substitute for it.
#
# Where self-care is not a ➕ choice but is prompted by fear or lack of alternatives, it can increase vulnerabilities and put people’s well-being at risk.
# https://t.co/dDDfj4PPEm https://t.co/T810wf0yJj
#     date: Fri Jun 25 11:47:52 +0000 2021
#     hashtags: ['SelfCare', 'PrimaryHealthCare']
#     likes: 123
#     retweets: 44
#     url: https://t.co/T810wf0yJj
#
# 10  score:  0.9999999999275693
# id: 1408416636084707335
#     username: World Health Organization (WHO)
#     text: Here is why you should get vaccinated even if you have had #COVID19 👇
#     date: Fri Jun 25 13:27:47 +0000 2021
#     hashtags: ['COVID19']
#     likes: 432
#     retweets: 221
#     url: None
#
# 11  score:  0.9999999999225551
# id: 1408173679499005960
#     username: World Health Organization (WHO)
#     text: Even after getting vaccinated against #COVID19, 𝗸𝗲𝗲𝗽 𝘁𝗮𝗸𝗶𝗻𝗴 𝗽𝗿𝗲𝗰𝗮𝘂𝘁𝗶𝗼𝗻𝘀 to protect family and friends. https://t.co/bnOGX254MB
#     date: Thu Jun 24 21:22:22 +0000 2021
#     hashtags: ['COVID19']
#     likes: 528
#     retweets: 259
#     url: https://t.co/bnOGX254MB
#
# 12  score:  0.9999999999120568
# id: 1408441069528924166
#     username: World Health Organization (WHO)
#     text: RT @WHO: Even after getting vaccinated against #COVID19, 𝗸𝗲𝗲𝗽 𝘁𝗮𝗸𝗶𝗻𝗴 𝗽𝗿𝗲𝗰𝗮𝘂𝘁𝗶𝗼𝗻𝘀 to protect family and friends. https://t.co/bnOGX254MB
#     date: Fri Jun 25 15:04:53 +0000 2021
#     hashtags: ['COVID19']
#     likes: 0
#     retweets: 259
#     url: https://t.co/bnOGX254MB
#
# 13  score:  0.9999999998901731
# id: 1408430077654798341
#     username: World Health Organization (WHO)
#     text: #SelfCare technologies help people look after their own sexual &amp; reproductive health:
#
# 🔹Self-injectable contraceptives
# 🔹HIV &amp;hepatitis C self-testing
# 🔹Self-sampling for HPV
# 🔹🤰 self-tests
# 🔹Ovulation predictor kits for fertility management
# https://t.co/dDDfj4PPEm
#     date: Fri Jun 25 14:21:12 +0000 2021
#     hashtags: ['SelfCare']
#     likes: 92
#     retweets: 24
#     url: None
#
# 14  score:  0.9999999998680841
# id: 1408365351734284289
#     username: World Health Organization (WHO)
#     text: #SelfCare is the ability of individuals, families and communities to:
#
# ✅ promote health
# ✅ prevent diseases
# ✅ maintain health
# ✅ cope with illness and disability
#
# with or without the support of a health worker 👨‍⚕️👩‍⚕️
#
# 👉 https://t.co/dDDfj4PPEm https://t.co/5iPNdMFnL7
#     date: Fri Jun 25 10:04:00 +0000 2021
#     hashtags: ['SelfCare']
#     likes: 199
#     retweets: 88
#     url: https://t.co/5iPNdMFnL7
#
# 15  score:  0.9999999998093907
# id: 1408447246060769292
#     username: World Health Organization (WHO)
#     text: Media briefing on #COVID19 with @DrTedros https://t.co/YiMdHDIfq0
#     date: Fri Jun 25 15:29:25 +0000 2021
#     hashtags: ['COVID19']
#     likes: 585
#     retweets: 196
#     url: None
#
# 16  score:  0.9999999997010565
# id: 1408350517428953091
#     username: World Health Organization (WHO)
#     text: To celebrate #SelfCare Month WHO is releasing new guidelines on Self-Care Interventions for Health.
#
# This new 📑 recognizes how people can actively take decisions for their own health and the health of their  ♥️  ones.
# https://t.co/xzditNF4NI
#     date: Fri Jun 25 09:05:03 +0000 2021
#     hashtags: ['SelfCare']
#     likes: 451
#     retweets: 165
#     url: None
#
# 17  score:  0.9999999995664284
# id: 1408447934681731074
#     username: World Health Organization (WHO)
#     text: @DrTedros "I know that globally there is currently a lot of concern about the #COVID19 Delta variant, and WHO is concerned about it too"-@DrTedros
# https://t.co/HQFrixFVOi
#     date: Fri Jun 25 15:32:09 +0000 2021
#     hashtags: ['COVID19']
#     likes: 54
#     retweets: 16
#     url: None
#
# 18  score:  0.9999999991645436
# id: 1408448096959410181
#     username: World Health Organization (WHO)
#     text: @DrTedros "Delta [variant] is the most transmissible of the #COVID19 variants identified so far, has been identified in at least 85 countries, and is spreading rapidly among unvaccinated populations"-@DrTedros
# https://t.co/HQFrixFVOi
#     date: Fri Jun 25 15:32:48 +0000 2021
#     hashtags: ['COVID19']
#     likes: 74
#     retweets: 44
#     url: None
#
# 19  score:  0.9999999985906873
# id: 1408512752264613894
#     username: World Health Organization (WHO)
#     text: RT @DrTedros: There's a lot of concern about the #COVID19 Delta variant - the most transmissible one identified so far. We must use tailore…
#     date: Fri Jun 25 19:49:43 +0000 2021
#     hashtags: ['COVID19']
#     likes: 0
#     retweets: 383
#     url: None
#
# 20  score:  0.9999999985631657
# id: 1408448204023205895
#     username: World Health Organization (WHO)
#     text: @DrTedros "As some countries ease public health and social measures, we are starting to see increases in #COVID19 transmission around the world. More cases means more hospitalizations, further stretching health workers and health systems, which increases the risk of death"-@DrTedros
#     date: Fri Jun 25 15:33:14 +0000 2021
#     hashtags: ['COVID19']
#     likes: 69
#     retweets: 33
#     url: None
# C:\Users\Harrison\anaconda3\lib\site-packages\ipykernel_launcher.py:19: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).

# %%
queries = ["covid", "vaccine", "global health", "end pandemic", "death risk"]
queries = [build_terms(query) for query in queries]

for query in queries:
    print(query)
    query_vec = avg_vector(w2v_model, query)
    results = rank_top_k(query_vec, tweet_vecs, title_index)
    print('------------------------')
# Out:
# ['covid']
# 1  score:  0.9999999999557492
# id: 1408027482113163265
#     username: World Health Organization (WHO)
#     text: RT @DrTedros: The #COVID19 situation in Africa is worrisome. Both the number of cases &amp; deaths are almost 40% higher than the week before.…
#     date: Thu Jun 24 11:41:26 +0000 2021
#     hashtags: ['COVID19']
#     likes: 0
#     retweets: 545
#     url: None
#
# 2  score:  0.9999999999369839
# id: 1408087054634799106
#     username: World Health Organization (WHO)
#     text: LIVE Q&amp;A on #COVID19 variants and vaccines with @doctorsoumya. #AskWHO https://t.co/RFfQvz1kmp
#     date: Thu Jun 24 15:38:09 +0000 2021
#     hashtags: ['COVID19', 'AskWHO']
#     likes: 508
#     retweets: 239
#     url: None
#
# 3  score:  0.9999999998806788
# id: 1408416636084707335
#     username: World Health Organization (WHO)
#     text: Here is why you should get vaccinated even if you have had #COVID19 👇
#     date: Fri Jun 25 13:27:47 +0000 2021
#     hashtags: ['COVID19']
#     likes: 432
#     retweets: 221
#     url: None
#
# 4  score:  0.9999999998774818
# id: 1408028717763416065
#     username: World Health Organization (WHO)
#     text: Today is Day 1 of #SelfCare Month!  💪
#
# Throughout this month we'll be sharing tips to help you protect your health - during the #COVID19 pandemic and beyond  👇
# https://t.co/0U9jroJSCx
#     date: Thu Jun 24 11:46:20 +0000 2021
#     hashtags: ['SelfCare', 'COVID19']
#     likes: 2528
#     retweets: 720
#     url: None
#
# 5  score:  0.999999999840768
# id: 1408017215190933507
#     username: World Health Organization (WHO)
#     text: The right to health means the right to control one’s health and body – including the sexual and reproductive health rights of women and girls – without interference https://t.co/0xs5xwkoTg
#
# #HealthForAll #StandUp4HumanRights https://t.co/qfh5PQ8S2D
#     date: Thu Jun 24 11:00:38 +0000 2021
#     hashtags: ['HealthForAll', 'StandUp4HumanRights']
#     likes: 287
#     retweets: 96
#     url: https://t.co/qfh5PQ8S2D
#
# 6  score:  0.9999999998313794
# id: 1408060159004270604
#     username: World Health Organization (WHO)
#     text: Take time each day for things you enjoy and to stay connected with those you 🤎
#
# ✅ Keep in touch with people you care about
# ✅ Think about what you can do for others
# ✅ Reach out to a trusted person or health worker if you need help
#
# 👉 https://t.co/0U9jroshdX https://t.co/yZpiyHMVgi
#     date: Thu Jun 24 13:51:17 +0000 2021
#     hashtags: []
#     likes: 509
#     retweets: 199
#     url: https://t.co/yZpiyHMVgi
#
# 7  score:  0.9999999998293104
# id: 1408027564321484802
#     username: World Health Organization (WHO)
#     text: RT @DrTedros: Very pleased to have spoken with Her Majesty Queen Mathilde of #Belgium about the upcoming 'Impact of violence against childr…
#     date: Thu Jun 24 11:41:45 +0000 2021
#     hashtags: ['Belgium']
#     likes: 0
#     retweets: 67
#     url: None
#
# 8  score:  0.9999999998286442
# id: 1408411083749171202
#     username: World Health Organization (WHO)
#     text: New #SelfCare recommendations include:
# ✅ provision of 🤰 self-tests with no prescription
# ✅ Pharmacy access to emergency contraception
# ✅ Self-management of iron &amp; folic acid supplementation
# ✅ Self-monitoring of blood glucose &amp; pressure during 🤰
#
# 👉 https://t.co/dDDfj4PPEm https://t.co/6SjRf6yUBD
#     date: Fri Jun 25 13:05:44 +0000 2021
#     hashtags: ['SelfCare']
#     likes: 159
#     retweets: 28
#     url: https://t.co/6SjRf6yUBD
#
# 9  score:  0.9999999997822699
# id: 1408441069528924166
#     username: World Health Organization (WHO)
#     text: RT @WHO: Even after getting vaccinated against #COVID19, 𝗸𝗲𝗲𝗽 𝘁𝗮𝗸𝗶𝗻𝗴 𝗽𝗿𝗲𝗰𝗮𝘂𝘁𝗶𝗼𝗻𝘀 to protect family and friends. https://t.co/bnOGX254MB
#     date: Fri Jun 25 15:04:53 +0000 2021
#     hashtags: ['COVID19']
#     likes: 0
#     retweets: 259
#     url: https://t.co/bnOGX254MB
#
# 10  score:  0.999999999767264
# id: 1408391491827945479
#     username: World Health Organization (WHO)
#     text: #SelfCare interventions should be complementary to #PrimaryHealthCare and not a substitute for it.
#
# Where self-care is not a ➕ choice but is prompted by fear or lack of alternatives, it can increase vulnerabilities and put people’s well-being at risk.
# https://t.co/dDDfj4PPEm https://t.co/T810wf0yJj
#     date: Fri Jun 25 11:47:52 +0000 2021
#     hashtags: ['SelfCare', 'PrimaryHealthCare']
#     likes: 123
#     retweets: 44
#     url: https://t.co/T810wf0yJj
#
# 11  score:  0.9999999997416961
# id: 1408041924460699655
#     username: World Health Organization (WHO)
#     text: Maintaining a healthy lifestyle is vital. This means:
#
# 🍊 Eating healthily
# 🏃‍♀️ Being physically active
# 🚭 Avoiding alcohol and tobacco
# 💤 Getting enough sleep
#
# 👉 https://t.co/0U9jroJSCx
#
# #SelfCare Month
# https://t.co/crF6gAgSQW
#     date: Thu Jun 24 12:38:49 +0000 2021
#     hashtags: ['SelfCare']
#     likes: 484
#     retweets: 208
#     url: https://t.co/crF6gAgSQW
#
# 12  score:  0.999999999672433
# id: 1408173679499005960
#     username: World Health Organization (WHO)
#     text: Even after getting vaccinated against #COVID19, 𝗸𝗲𝗲𝗽 𝘁𝗮𝗸𝗶𝗻𝗴 𝗽𝗿𝗲𝗰𝗮𝘂𝘁𝗶𝗼𝗻𝘀 to protect family and friends. https://t.co/bnOGX254MB
#     date: Thu Jun 24 21:22:22 +0000 2021
#     hashtags: ['COVID19']
#     likes: 528
#     retweets: 259
#     url: https://t.co/bnOGX254MB
#
# 13  score:  0.9999999996694606
# id: 1408430077654798341
#     username: World Health Organization (WHO)
#     text: #SelfCare technologies help people look after their own sexual &amp; reproductive health:
#
# 🔹Self-injectable contraceptives
# 🔹HIV &amp;hepatitis C self-testing
# 🔹Self-sampling for HPV
# 🔹🤰 self-tests
# 🔹Ovulation predictor kits for fertility management
# https://t.co/dDDfj4PPEm
#     date: Fri Jun 25 14:21:12 +0000 2021
#     hashtags: ['SelfCare']
#     likes: 92
#     retweets: 24
#     url: None
#
# 14  score:  0.9999999995748823
# id: 1408365351734284289
#     username: World Health Organization (WHO)
#     text: #SelfCare is the ability of individuals, families and communities to:
#
# ✅ promote health
# ✅ prevent diseases
# ✅ maintain health
# ✅ cope with illness and disability
#
# with or without the support of a health worker 👨‍⚕️👩‍⚕️
#
# 👉 https://t.co/dDDfj4PPEm https://t.co/5iPNdMFnL7
#     date: Fri Jun 25 10:04:00 +0000 2021
#     hashtags: ['SelfCare']
#     likes: 199
#     retweets: 88
#     url: https://t.co/5iPNdMFnL7
#
# 15  score:  0.9999999995182761
# id: 1408447246060769292
#     username: World Health Organization (WHO)
#     text: Media briefing on #COVID19 with @DrTedros https://t.co/YiMdHDIfq0
#     date: Fri Jun 25 15:29:25 +0000 2021
#     hashtags: ['COVID19']
#     likes: 585
#     retweets: 196
#     url: None
#
# 16  score:  0.9999999992803187
# id: 1408350517428953091
#     username: World Health Organization (WHO)
#     text: To celebrate #SelfCare Month WHO is releasing new guidelines on Self-Care Interventions for Health.
#
# This new 📑 recognizes how people can actively take decisions for their own health and the health of their  ♥️  ones.
# https://t.co/xzditNF4NI
#     date: Fri Jun 25 09:05:03 +0000 2021
#     hashtags: ['SelfCare']
#     likes: 451
#     retweets: 165
#     url: None
#
# 17  score:  0.9999999991091478
# id: 1408447934681731074
#     username: World Health Organization (WHO)
#     text: @DrTedros "I know that globally there is currently a lot of concern about the #COVID19 Delta variant, and WHO is concerned about it too"-@DrTedros
# https://t.co/HQFrixFVOi
#     date: Fri Jun 25 15:32:09 +0000 2021
#     hashtags: ['COVID19']
#     likes: 54
#     retweets: 16
#     url: None
#
# 18  score:  0.9999999985400343
# id: 1408448096959410181
#     username: World Health Organization (WHO)
#     text: @DrTedros "Delta [variant] is the most transmissible of the #COVID19 variants identified so far, has been identified in at least 85 countries, and is spreading rapidly among unvaccinated populations"-@DrTedros
# https://t.co/HQFrixFVOi
#     date: Fri Jun 25 15:32:48 +0000 2021
#     hashtags: ['COVID19']
#     likes: 74
#     retweets: 44
#     url: None
#
# 19  score:  0.9999999982807084
# id: 1409579171043491846
#     username: World Health Organization (WHO)
#     text: Women and girls continue to face discrimination and marginalization, visible in pay gaps, especially in the health workforce, and the high prevalence of gender-based violence, including harassment.
#
# We must #ActForEqual 💪 https://t.co/fPz78iTyXX
#     date: Mon Jun 28 18:27:17 +0000 2021
#     hashtags: ['ActForEqual']
#     likes: 208
#     retweets: 57
#     url: https://t.co/fPz78iTyXX
#
# 20  score:  0.9999999982608684
# id: 1409568583294783493
#     username: World Health Organization (WHO)
#     text: WHO has teamed up with @bmj_latest and @UNU_IIGH to produce a special series of the BMJ podcast, bringing together experts and advocates reflecting on progress 26 years on from the #BeijingPlatform
#
# More info 👇
# https://t.co/2DNevP1x2v https://t.co/VM5Gx29cHJ
#     date: Mon Jun 28 17:45:13 +0000 2021
#     hashtags: ['BeijingPlatform']
#     likes: 111
#     retweets: 34
#     url: https://t.co/VM5Gx29cHJ
#
# ------------------------
# ['vaccin']
# 1  score:  0.9999999999617905
# id: 1408027482113163265
#     username: World Health Organization (WHO)
#     text: RT @DrTedros: The #COVID19 situation in Africa is worrisome. Both the number of cases &amp; deaths are almost 40% higher than the week before.…
#     date: Thu Jun 24 11:41:26 +0000 2021
#     hashtags: ['COVID19']
#     likes: 0
#     retweets: 545
#     url: None
#
# 2  score:  0.9999999999461249
# id: 1408087054634799106
#     username: World Health Organization (WHO)
#     text: LIVE Q&amp;A on #COVID19 variants and vaccines with @doctorsoumya. #AskWHO https://t.co/RFfQvz1kmp
#     date: Thu Jun 24 15:38:09 +0000 2021
#     hashtags: ['COVID19', 'AskWHO']
#     likes: 508
#     retweets: 239
#     url: None
#
# 3  score:  0.9999999998976471
# id: 1408028717763416065
#     username: World Health Organization (WHO)
#     text: Today is Day 1 of #SelfCare Month!  💪
#
# Throughout this month we'll be sharing tips to help you protect your health - during the #COVID19 pandemic and beyond  👇
# https://t.co/0U9jroJSCx
#     date: Thu Jun 24 11:46:20 +0000 2021
#     hashtags: ['SelfCare', 'COVID19']
#     likes: 2528
#     retweets: 720
#     url: None
#
# 4  score:  0.9999999998922088
# id: 1408416636084707335
#     username: World Health Organization (WHO)
#     text: Here is why you should get vaccinated even if you have had #COVID19 👇
#     date: Fri Jun 25 13:27:47 +0000 2021
#     hashtags: ['COVID19']
#     likes: 432
#     retweets: 221
#     url: None
#
# 5  score:  0.9999999998646658
# id: 1408017215190933507
#     username: World Health Organization (WHO)
#     text: The right to health means the right to control one’s health and body – including the sexual and reproductive health rights of women and girls – without interference https://t.co/0xs5xwkoTg
#
# #HealthForAll #StandUp4HumanRights https://t.co/qfh5PQ8S2D
#     date: Thu Jun 24 11:00:38 +0000 2021
#     hashtags: ['HealthForAll', 'StandUp4HumanRights']
#     likes: 287
#     retweets: 96
#     url: https://t.co/qfh5PQ8S2D
#
# 6  score:  0.9999999998590511
# id: 1408060159004270604
#     username: World Health Organization (WHO)
#     text: Take time each day for things you enjoy and to stay connected with those you 🤎
#
# ✅ Keep in touch with people you care about
# ✅ Think about what you can do for others
# ✅ Reach out to a trusted person or health worker if you need help
#
# 👉 https://t.co/0U9jroshdX https://t.co/yZpiyHMVgi
#     date: Thu Jun 24 13:51:17 +0000 2021
#     hashtags: []
#     likes: 509
#     retweets: 199
#     url: https://t.co/yZpiyHMVgi
#
# 7  score:  0.9999999998563578
# id: 1408027564321484802
#     username: World Health Organization (WHO)
#     text: RT @DrTedros: Very pleased to have spoken with Her Majesty Queen Mathilde of #Belgium about the upcoming 'Impact of violence against childr…
#     date: Thu Jun 24 11:41:45 +0000 2021
#     hashtags: ['Belgium']
#     likes: 0
#     retweets: 67
#     url: None
#
# 8  score:  0.9999999998514437
# id: 1408411083749171202
#     username: World Health Organization (WHO)
#     text: New #SelfCare recommendations include:
# ✅ provision of 🤰 self-tests with no prescription
# ✅ Pharmacy access to emergency contraception
# ✅ Self-management of iron &amp; folic acid supplementation
# ✅ Self-monitoring of blood glucose &amp; pressure during 🤰
#
# 👉 https://t.co/dDDfj4PPEm https://t.co/6SjRf6yUBD
#     date: Fri Jun 25 13:05:44 +0000 2021
#     hashtags: ['SelfCare']
#     likes: 159
#     retweets: 28
#     url: https://t.co/6SjRf6yUBD
#
# 9  score:  0.9999999998079768
# id: 1408441069528924166
#     username: World Health Organization (WHO)
#     text: RT @WHO: Even after getting vaccinated against #COVID19, 𝗸𝗲𝗲𝗽 𝘁𝗮𝗸𝗶𝗻𝗴 𝗽𝗿𝗲𝗰𝗮𝘂𝘁𝗶𝗼𝗻𝘀 to protect family and friends. https://t.co/bnOGX254MB
#     date: Fri Jun 25 15:04:53 +0000 2021
#     hashtags: ['COVID19']
#     likes: 0
#     retweets: 259
#     url: https://t.co/bnOGX254MB
#
# 10  score:  0.9999999997999203
# id: 1408391491827945479
#     username: World Health Organization (WHO)
#     text: #SelfCare interventions should be complementary to #PrimaryHealthCare and not a substitute for it.
#
# Where self-care is not a ➕ choice but is prompted by fear or lack of alternatives, it can increase vulnerabilities and put people’s well-being at risk.
# https://t.co/dDDfj4PPEm https://t.co/T810wf0yJj
#     date: Fri Jun 25 11:47:52 +0000 2021
#     hashtags: ['SelfCare', 'PrimaryHealthCare']
#     likes: 123
#     retweets: 44
#     url: https://t.co/T810wf0yJj
#
# 11  score:  0.9999999997796996
# id: 1408041924460699655
#     username: World Health Organization (WHO)
#     text: Maintaining a healthy lifestyle is vital. This means:
#
# 🍊 Eating healthily
# 🏃‍♀️ Being physically active
# 🚭 Avoiding alcohol and tobacco
# 💤 Getting enough sleep
#
# 👉 https://t.co/0U9jroJSCx
#
# #SelfCare Month
# https://t.co/crF6gAgSQW
#     date: Thu Jun 24 12:38:49 +0000 2021
#     hashtags: ['SelfCare']
#     likes: 484
#     retweets: 208
#     url: https://t.co/crF6gAgSQW
#
# 12  score:  0.9999999997183016
# id: 1408173679499005960
#     username: World Health Organization (WHO)
#     text: Even after getting vaccinated against #COVID19, 𝗸𝗲𝗲𝗽 𝘁𝗮𝗸𝗶𝗻𝗴 𝗽𝗿𝗲𝗰𝗮𝘂𝘁𝗶𝗼𝗻𝘀 to protect family and friends. https://t.co/bnOGX254MB
#     date: Thu Jun 24 21:22:22 +0000 2021
#     hashtags: ['COVID19']
#     likes: 528
#     retweets: 259
#     url: https://t.co/bnOGX254MB
#
# 13  score:  0.9999999997097004
# id: 1408430077654798341
#     username: World Health Organization (WHO)
#     text: #SelfCare technologies help people look after their own sexual &amp; reproductive health:
#
# 🔹Self-injectable contraceptives
# 🔹HIV &amp;hepatitis C self-testing
# 🔹Self-sampling for HPV
# 🔹🤰 self-tests
# 🔹Ovulation predictor kits for fertility management
# https://t.co/dDDfj4PPEm
#     date: Fri Jun 25 14:21:12 +0000 2021
#     hashtags: ['SelfCare']
#     likes: 92
#     retweets: 24
#     url: None
#
# 14  score:  0.9999999996271627
# id: 1408365351734284289
#     username: World Health Organization (WHO)
#     text: #SelfCare is the ability of individuals, families and communities to:
#
# ✅ promote health
# ✅ prevent diseases
# ✅ maintain health
# ✅ cope with illness and disability
#
# with or without the support of a health worker 👨‍⚕️👩‍⚕️
#
# 👉 https://t.co/dDDfj4PPEm https://t.co/5iPNdMFnL7
#     date: Fri Jun 25 10:04:00 +0000 2021
#     hashtags: ['SelfCare']
#     likes: 199
#     retweets: 88
#     url: https://t.co/5iPNdMFnL7
#
# 15  score:  0.999999999570317
# id: 1408447246060769292
#     username: World Health Organization (WHO)
#     text: Media briefing on #COVID19 with @DrTedros https://t.co/YiMdHDIfq0
#     date: Fri Jun 25 15:29:25 +0000 2021
#     hashtags: ['COVID19']
#     likes: 585
#     retweets: 196
#     url: None
#
# 16  score:  0.9999999993541809
# id: 1408350517428953091
#     username: World Health Organization (WHO)
#     text: To celebrate #SelfCare Month WHO is releasing new guidelines on Self-Care Interventions for Health.
#
# This new 📑 recognizes how people can actively take decisions for their own health and the health of their  ♥️  ones.
# https://t.co/xzditNF4NI
#     date: Fri Jun 25 09:05:03 +0000 2021
#     hashtags: ['SelfCare']
#     likes: 451
#     retweets: 165
#     url: None
#
# 17  score:  0.9999999991917377
# id: 1408447934681731074
#     username: World Health Organization (WHO)
#     text: @DrTedros "I know that globally there is currently a lot of concern about the #COVID19 Delta variant, and WHO is concerned about it too"-@DrTedros
# https://t.co/HQFrixFVOi
#     date: Fri Jun 25 15:32:09 +0000 2021
#     hashtags: ['COVID19']
#     likes: 54
#     retweets: 16
#     url: None
#
# 18  score:  0.9999999986515898
# id: 1408448096959410181
#     username: World Health Organization (WHO)
#     text: @DrTedros "Delta [variant] is the most transmissible of the #COVID19 variants identified so far, has been identified in at least 85 countries, and is spreading rapidly among unvaccinated populations"-@DrTedros
# https://t.co/HQFrixFVOi
#     date: Fri Jun 25 15:32:48 +0000 2021
#     hashtags: ['COVID19']
#     likes: 74
#     retweets: 44
#     url: None
#
# 19  score:  0.9999999982567895
# id: 1409579171043491846
#     username: World Health Organization (WHO)
#     text: Women and girls continue to face discrimination and marginalization, visible in pay gaps, especially in the health workforce, and the high prevalence of gender-based violence, including harassment.
#
# We must #ActForEqual 💪 https://t.co/fPz78iTyXX
#     date: Mon Jun 28 18:27:17 +0000 2021
#     hashtags: ['ActForEqual']
#     likes: 208
#     retweets: 57
#     url: https://t.co/fPz78iTyXX
#
# 20  score:  0.9999999982472811
# id: 1409568583294783493
#     username: World Health Organization (WHO)
#     text: WHO has teamed up with @bmj_latest and @UNU_IIGH to produce a special series of the BMJ podcast, bringing together experts and advocates reflecting on progress 26 years on from the #BeijingPlatform
#
# More info 👇
# https://t.co/2DNevP1x2v https://t.co/VM5Gx29cHJ
#     date: Mon Jun 28 17:45:13 +0000 2021
#     hashtags: ['BeijingPlatform']
#     likes: 111
#     retweets: 34
#     url: https://t.co/VM5Gx29cHJ
#
# ------------------------
# ['global', 'health']
# 1  score:  0.999999999983562
# id: 1408027482113163265
#     username: World Health Organization (WHO)
#     text: RT @DrTedros: The #COVID19 situation in Africa is worrisome. Both the number of cases &amp; deaths are almost 40% higher than the week before.…
#     date: Thu Jun 24 11:41:26 +0000 2021
#     hashtags: ['COVID19']
#     likes: 0
#     retweets: 545
#     url: None
#
# 2  score:  0.9999999999685083
# id: 1408087054634799106
#     username: World Health Organization (WHO)
#     text: LIVE Q&amp;A on #COVID19 variants and vaccines with @doctorsoumya. #AskWHO https://t.co/RFfQvz1kmp
#     date: Thu Jun 24 15:38:09 +0000 2021
#     hashtags: ['COVID19', 'AskWHO']
#     likes: 508
#     retweets: 239
#     url: None
#
# 3  score:  0.9999999999439726
# id: 1408028717763416065
#     username: World Health Organization (WHO)
#     text: Today is Day 1 of #SelfCare Month!  💪
#
# Throughout this month we'll be sharing tips to help you protect your health - during the #COVID19 pandemic and beyond  👇
# https://t.co/0U9jroJSCx
#     date: Thu Jun 24 11:46:20 +0000 2021
#     hashtags: ['SelfCare', 'COVID19']
#     likes: 2528
#     retweets: 720
#     url: None
#
# 4  score:  0.9999999999219442
# id: 1408017215190933507
#     username: World Health Organization (WHO)
#     text: The right to health means the right to control one’s health and body – including the sexual and reproductive health rights of women and girls – without interference https://t.co/0xs5xwkoTg
#
# #HealthForAll #StandUp4HumanRights https://t.co/qfh5PQ8S2D
#     date: Thu Jun 24 11:00:38 +0000 2021
#     hashtags: ['HealthForAll', 'StandUp4HumanRights']
#     likes: 287
#     retweets: 96
#     url: https://t.co/qfh5PQ8S2D
#
# 5  score:  0.9999999999111837
# id: 1408027564321484802
#     username: World Health Organization (WHO)
#     text: RT @DrTedros: Very pleased to have spoken with Her Majesty Queen Mathilde of #Belgium about the upcoming 'Impact of violence against childr…
#     date: Thu Jun 24 11:41:45 +0000 2021
#     hashtags: ['Belgium']
#     likes: 0
#     retweets: 67
#     url: None
#
# 6  score:  0.9999999999107896
# id: 1408060159004270604
#     username: World Health Organization (WHO)
#     text: Take time each day for things you enjoy and to stay connected with those you 🤎
#
# ✅ Keep in touch with people you care about
# ✅ Think about what you can do for others
# ✅ Reach out to a trusted person or health worker if you need help
#
# 👉 https://t.co/0U9jroshdX https://t.co/yZpiyHMVgi
#     date: Thu Jun 24 13:51:17 +0000 2021
#     hashtags: []
#     likes: 509
#     retweets: 199
#     url: https://t.co/yZpiyHMVgi
#
# 7  score:  0.9999999999039993
# id: 1408416636084707335
#     username: World Health Organization (WHO)
#     text: Here is why you should get vaccinated even if you have had #COVID19 👇
#     date: Fri Jun 25 13:27:47 +0000 2021
#     hashtags: ['COVID19']
#     likes: 432
#     retweets: 221
#     url: None
#
# 8  score:  0.9999999998818366
# id: 1408411083749171202
#     username: World Health Organization (WHO)
#     text: New #SelfCare recommendations include:
# ✅ provision of 🤰 self-tests with no prescription
# ✅ Pharmacy access to emergency contraception
# ✅ Self-management of iron &amp; folic acid supplementation
# ✅ Self-monitoring of blood glucose &amp; pressure during 🤰
#
# 👉 https://t.co/dDDfj4PPEm https://t.co/6SjRf6yUBD
#     date: Fri Jun 25 13:05:44 +0000 2021
#     hashtags: ['SelfCare']
#     likes: 159
#     retweets: 28
#     url: https://t.co/6SjRf6yUBD
#
# 9  score:  0.9999999998466448
# id: 1408041924460699655
#     username: World Health Organization (WHO)
#     text: Maintaining a healthy lifestyle is vital. This means:
#
# 🍊 Eating healthily
# 🏃‍♀️ Being physically active
# 🚭 Avoiding alcohol and tobacco
# 💤 Getting enough sleep
#
# 👉 https://t.co/0U9jroJSCx
#
# #SelfCare Month
# https://t.co/crF6gAgSQW
#     date: Thu Jun 24 12:38:49 +0000 2021
#     hashtags: ['SelfCare']
#     likes: 484
#     retweets: 208
#     url: https://t.co/crF6gAgSQW
#
# 10  score:  0.9999999998437545
# id: 1408391491827945479
#     username: World Health Organization (WHO)
#     text: #SelfCare interventions should be complementary to #PrimaryHealthCare and not a substitute for it.
#
# Where self-care is not a ➕ choice but is prompted by fear or lack of alternatives, it can increase vulnerabilities and put people’s well-being at risk.
# https://t.co/dDDfj4PPEm https://t.co/T810wf0yJj
#     date: Fri Jun 25 11:47:52 +0000 2021
#     hashtags: ['SelfCare', 'PrimaryHealthCare']
#     likes: 123
#     retweets: 44
#     url: https://t.co/T810wf0yJj
#
# 11  score:  0.9999999998374961
# id: 1408441069528924166
#     username: World Health Organization (WHO)
#     text: RT @WHO: Even after getting vaccinated against #COVID19, 𝗸𝗲𝗲𝗽 𝘁𝗮𝗸𝗶𝗻𝗴 𝗽𝗿𝗲𝗰𝗮𝘂𝘁𝗶𝗼𝗻𝘀 to protect family and friends. https://t.co/bnOGX254MB
#     date: Fri Jun 25 15:04:53 +0000 2021
#     hashtags: ['COVID19']
#     likes: 0
#     retweets: 259
#     url: https://t.co/bnOGX254MB
#
# 12  score:  0.9999999997890577
# id: 1408173679499005960
#     username: World Health Organization (WHO)
#     text: Even after getting vaccinated against #COVID19, 𝗸𝗲𝗲𝗽 𝘁𝗮𝗸𝗶𝗻𝗴 𝗽𝗿𝗲𝗰𝗮𝘂𝘁𝗶𝗼𝗻𝘀 to protect family and friends. https://t.co/bnOGX254MB
#     date: Thu Jun 24 21:22:22 +0000 2021
#     hashtags: ['COVID19']
#     likes: 528
#     retweets: 259
#     url: https://t.co/bnOGX254MB
#
# 13  score:  0.9999999997638773
# id: 1408430077654798341
#     username: World Health Organization (WHO)
#     text: #SelfCare technologies help people look after their own sexual &amp; reproductive health:
#
# 🔹Self-injectable contraceptives
# 🔹HIV &amp;hepatitis C self-testing
# 🔹Self-sampling for HPV
# 🔹🤰 self-tests
# 🔹Ovulation predictor kits for fertility management
# https://t.co/dDDfj4PPEm
#     date: Fri Jun 25 14:21:12 +0000 2021
#     hashtags: ['SelfCare']
#     likes: 92
#     retweets: 24
#     url: None
#
# 14  score:  0.9999999997054553
# id: 1408365351734284289
#     username: World Health Organization (WHO)
#     text: #SelfCare is the ability of individuals, families and communities to:
#
# ✅ promote health
# ✅ prevent diseases
# ✅ maintain health
# ✅ cope with illness and disability
#
# with or without the support of a health worker 👨‍⚕️👩‍⚕️
#
# 👉 https://t.co/dDDfj4PPEm https://t.co/5iPNdMFnL7
#     date: Fri Jun 25 10:04:00 +0000 2021
#     hashtags: ['SelfCare']
#     likes: 199
#     retweets: 88
#     url: https://t.co/5iPNdMFnL7
#
# 15  score:  0.9999999996395785
# id: 1408447246060769292
#     username: World Health Organization (WHO)
#     text: Media briefing on #COVID19 with @DrTedros https://t.co/YiMdHDIfq0
#     date: Fri Jun 25 15:29:25 +0000 2021
#     hashtags: ['COVID19']
#     likes: 585
#     retweets: 196
#     url: None
#
# 16  score:  0.9999999994665131
# id: 1408350517428953091
#     username: World Health Organization (WHO)
#     text: To celebrate #SelfCare Month WHO is releasing new guidelines on Self-Care Interventions for Health.
#
# This new 📑 recognizes how people can actively take decisions for their own health and the health of their  ♥️  ones.
# https://t.co/xzditNF4NI
#     date: Fri Jun 25 09:05:03 +0000 2021
#     hashtags: ['SelfCare']
#     likes: 451
#     retweets: 165
#     url: None
#
# 17  score:  0.9999999992995052
# id: 1408447934681731074
#     username: World Health Organization (WHO)
#     text: @DrTedros "I know that globally there is currently a lot of concern about the #COVID19 Delta variant, and WHO is concerned about it too"-@DrTedros
# https://t.co/HQFrixFVOi
#     date: Fri Jun 25 15:32:09 +0000 2021
#     hashtags: ['COVID19']
#     likes: 54
#     retweets: 16
#     url: None
#
# 18  score:  0.999999998799102
# id: 1408448096959410181
#     username: World Health Organization (WHO)
#     text: @DrTedros "Delta [variant] is the most transmissible of the #COVID19 variants identified so far, has been identified in at least 85 countries, and is spreading rapidly among unvaccinated populations"-@DrTedros
# https://t.co/HQFrixFVOi
#     date: Fri Jun 25 15:32:48 +0000 2021
#     hashtags: ['COVID19']
#     likes: 74
#     retweets: 44
#     url: None
#
# 19  score:  0.999999998206633
# id: 1409556378713309186
#     username: World Health Organization (WHO)
#     text: Without advancing gender equality in the health workforce, across communities and across the world 🌍 we cannot attain #HealthForAll
#
# 👉 https://t.co/7OfZKyPi6S https://t.co/1w9Un4vsSD
#     date: Mon Jun 28 16:56:43 +0000 2021
#     hashtags: ['HealthForAll']
#     likes: 191
#     retweets: 38
#     url: https://t.co/1w9Un4vsSD
#
# 20  score:  0.9999999981926517
# id: 1409568583294783493
#     username: World Health Organization (WHO)
#     text: WHO has teamed up with @bmj_latest and @UNU_IIGH to produce a special series of the BMJ podcast, bringing together experts and advocates reflecting on progress 26 years on from the #BeijingPlatform
#
# More info 👇
# https://t.co/2DNevP1x2v https://t.co/VM5Gx29cHJ
#     date: Mon Jun 28 17:45:13 +0000 2021
#     hashtags: ['BeijingPlatform']
#     likes: 111
#     retweets: 34
#     url: https://t.co/VM5Gx29cHJ
#
# ------------------------
# ['end', 'pandem']
# 1  score:  0.9999999998639177
# id: 1408027482113163265
#     username: World Health Organization (WHO)
#     text: RT @DrTedros: The #COVID19 situation in Africa is worrisome. Both the number of cases &amp; deaths are almost 40% higher than the week before.…
#     date: Thu Jun 24 11:41:26 +0000 2021
#     hashtags: ['COVID19']
#     likes: 0
#     retweets: 545
#     url: None
#
# 2  score:  0.9999999998443958
# id: 1408087054634799106
#     username: World Health Organization (WHO)
#     text: LIVE Q&amp;A on #COVID19 variants and vaccines with @doctorsoumya. #AskWHO https://t.co/RFfQvz1kmp
#     date: Thu Jun 24 15:38:09 +0000 2021
#     hashtags: ['COVID19', 'AskWHO']
#     likes: 508
#     retweets: 239
#     url: None
#
# 3  score:  0.9999999998027601
# id: 1408416636084707335
#     username: World Health Organization (WHO)
#     text: Here is why you should get vaccinated even if you have had #COVID19 👇
#     date: Fri Jun 25 13:27:47 +0000 2021
#     hashtags: ['COVID19']
#     likes: 432
#     retweets: 221
#     url: None
#
# 4  score:  0.9999999997566479
# id: 1408028717763416065
#     username: World Health Organization (WHO)
#     text: Today is Day 1 of #SelfCare Month!  💪
#
# Throughout this month we'll be sharing tips to help you protect your health - during the #COVID19 pandemic and beyond  👇
# https://t.co/0U9jroJSCx
#     date: Thu Jun 24 11:46:20 +0000 2021
#     hashtags: ['SelfCare', 'COVID19']
#     likes: 2528
#     retweets: 720
#     url: None
#
# 5  score:  0.999999999727924
# id: 1408411083749171202
#     username: World Health Organization (WHO)
#     text: New #SelfCare recommendations include:
# ✅ provision of 🤰 self-tests with no prescription
# ✅ Pharmacy access to emergency contraception
# ✅ Self-management of iron &amp; folic acid supplementation
# ✅ Self-monitoring of blood glucose &amp; pressure during 🤰
#
# 👉 https://t.co/dDDfj4PPEm https://t.co/6SjRf6yUBD
#     date: Fri Jun 25 13:05:44 +0000 2021
#     hashtags: ['SelfCare']
#     likes: 159
#     retweets: 28
#     url: https://t.co/6SjRf6yUBD
#
# 6  score:  0.9999999997059077
# id: 1408017215190933507
#     username: World Health Organization (WHO)
#     text: The right to health means the right to control one’s health and body – including the sexual and reproductive health rights of women and girls – without interference https://t.co/0xs5xwkoTg
#
# #HealthForAll #StandUp4HumanRights https://t.co/qfh5PQ8S2D
#     date: Thu Jun 24 11:00:38 +0000 2021
#     hashtags: ['HealthForAll', 'StandUp4HumanRights']
#     likes: 287
#     retweets: 96
#     url: https://t.co/qfh5PQ8S2D
#
# 7  score:  0.9999999997044186
# id: 1408060159004270604
#     username: World Health Organization (WHO)
#     text: Take time each day for things you enjoy and to stay connected with those you 🤎
#
# ✅ Keep in touch with people you care about
# ✅ Think about what you can do for others
# ✅ Reach out to a trusted person or health worker if you need help
#
# 👉 https://t.co/0U9jroshdX https://t.co/yZpiyHMVgi
#     date: Thu Jun 24 13:51:17 +0000 2021
#     hashtags: []
#     likes: 509
#     retweets: 199
#     url: https://t.co/yZpiyHMVgi
#
# 8  score:  0.9999999996985243
# id: 1408027564321484802
#     username: World Health Organization (WHO)
#     text: RT @DrTedros: Very pleased to have spoken with Her Majesty Queen Mathilde of #Belgium about the upcoming 'Impact of violence against childr…
#     date: Thu Jun 24 11:41:45 +0000 2021
#     hashtags: ['Belgium']
#     likes: 0
#     retweets: 67
#     url: None
#
# 9  score:  0.9999999996829764
# id: 1408441069528924166
#     username: World Health Organization (WHO)
#     text: RT @WHO: Even after getting vaccinated against #COVID19, 𝗸𝗲𝗲𝗽 𝘁𝗮𝗸𝗶𝗻𝗴 𝗽𝗿𝗲𝗰𝗮𝘂𝘁𝗶𝗼𝗻𝘀 to protect family and friends. https://t.co/bnOGX254MB
#     date: Fri Jun 25 15:04:53 +0000 2021
#     hashtags: ['COVID19']
#     likes: 0
#     retweets: 259
#     url: https://t.co/bnOGX254MB
#
# 10  score:  0.9999999996498086
# id: 1408391491827945479
#     username: World Health Organization (WHO)
#     text: #SelfCare interventions should be complementary to #PrimaryHealthCare and not a substitute for it.
#
# Where self-care is not a ➕ choice but is prompted by fear or lack of alternatives, it can increase vulnerabilities and put people’s well-being at risk.
# https://t.co/dDDfj4PPEm https://t.co/T810wf0yJj
#     date: Fri Jun 25 11:47:52 +0000 2021
#     hashtags: ['SelfCare', 'PrimaryHealthCare']
#     likes: 123
#     retweets: 44
#     url: https://t.co/T810wf0yJj
#
# 11  score:  0.9999999995961704
# id: 1408041924460699655
#     username: World Health Organization (WHO)
#     text: Maintaining a healthy lifestyle is vital. This means:
#
# 🍊 Eating healthily
# 🏃‍♀️ Being physically active
# 🚭 Avoiding alcohol and tobacco
# 💤 Getting enough sleep
#
# 👉 https://t.co/0U9jroJSCx
#
# #SelfCare Month
# https://t.co/crF6gAgSQW
#     date: Thu Jun 24 12:38:49 +0000 2021
#     hashtags: ['SelfCare']
#     likes: 484
#     retweets: 208
#     url: https://t.co/crF6gAgSQW
#
# 12  score:  0.9999999995408979
# id: 1408430077654798341
#     username: World Health Organization (WHO)
#     text: #SelfCare technologies help people look after their own sexual &amp; reproductive health:
#
# 🔹Self-injectable contraceptives
# 🔹HIV &amp;hepatitis C self-testing
# 🔹Self-sampling for HPV
# 🔹🤰 self-tests
# 🔹Ovulation predictor kits for fertility management
# https://t.co/dDDfj4PPEm
#     date: Fri Jun 25 14:21:12 +0000 2021
#     hashtags: ['SelfCare']
#     likes: 92
#     retweets: 24
#     url: None
#
# 13  score:  0.9999999995247374
# id: 1408173679499005960
#     username: World Health Organization (WHO)
#     text: Even after getting vaccinated against #COVID19, 𝗸𝗲𝗲𝗽 𝘁𝗮𝗸𝗶𝗻𝗴 𝗽𝗿𝗲𝗰𝗮𝘂𝘁𝗶𝗼𝗻𝘀 to protect family and friends. https://t.co/bnOGX254MB
#     date: Thu Jun 24 21:22:22 +0000 2021
#     hashtags: ['COVID19']
#     likes: 528
#     retweets: 259
#     url: https://t.co/bnOGX254MB
#
# 14  score:  0.9999999994170427
# id: 1408365351734284289
#     username: World Health Organization (WHO)
#     text: #SelfCare is the ability of individuals, families and communities to:
#
# ✅ promote health
# ✅ prevent diseases
# ✅ maintain health
# ✅ cope with illness and disability
#
# with or without the support of a health worker 👨‍⚕️👩‍⚕️
#
# 👉 https://t.co/dDDfj4PPEm https://t.co/5iPNdMFnL7
#     date: Fri Jun 25 10:04:00 +0000 2021
#     hashtags: ['SelfCare']
#     likes: 199
#     retweets: 88
#     url: https://t.co/5iPNdMFnL7
#
# 15  score:  0.9999999993713625
# id: 1408447246060769292
#     username: World Health Organization (WHO)
#     text: Media briefing on #COVID19 with @DrTedros https://t.co/YiMdHDIfq0
#     date: Fri Jun 25 15:29:25 +0000 2021
#     hashtags: ['COVID19']
#     likes: 585
#     retweets: 196
#     url: None
#
# 16  score:  0.9999999990831658
# id: 1408350517428953091
#     username: World Health Organization (WHO)
#     text: To celebrate #SelfCare Month WHO is releasing new guidelines on Self-Care Interventions for Health.
#
# This new 📑 recognizes how people can actively take decisions for their own health and the health of their  ♥️  ones.
# https://t.co/xzditNF4NI
#     date: Fri Jun 25 09:05:03 +0000 2021
#     hashtags: ['SelfCare']
#     likes: 451
#     retweets: 165
#     url: None
#
# 17  score:  0.9999999989173451
# id: 1408447934681731074
#     username: World Health Organization (WHO)
#     text: @DrTedros "I know that globally there is currently a lot of concern about the #COVID19 Delta variant, and WHO is concerned about it too"-@DrTedros
# https://t.co/HQFrixFVOi
#     date: Fri Jun 25 15:32:09 +0000 2021
#     hashtags: ['COVID19']
#     likes: 54
#     retweets: 16
#     url: None
#
# 18  score:  0.9999999983011529
# id: 1408448096959410181
#     username: World Health Organization (WHO)
#     text: @DrTedros "Delta [variant] is the most transmissible of the #COVID19 variants identified so far, has been identified in at least 85 countries, and is spreading rapidly among unvaccinated populations"-@DrTedros
# https://t.co/HQFrixFVOi
#     date: Fri Jun 25 15:32:48 +0000 2021
#     hashtags: ['COVID19']
#     likes: 74
#     retweets: 44
#     url: None
#
# 19  score:  0.9999999982669098
# id: 1409579171043491846
#     username: World Health Organization (WHO)
#     text: Women and girls continue to face discrimination and marginalization, visible in pay gaps, especially in the health workforce, and the high prevalence of gender-based violence, including harassment.
#
# We must #ActForEqual 💪 https://t.co/fPz78iTyXX
#     date: Mon Jun 28 18:27:17 +0000 2021
#     hashtags: ['ActForEqual']
#     likes: 208
#     retweets: 57
#     url: https://t.co/fPz78iTyXX
#
# 20  score:  0.9999999982497038
# id: 1409586811823792140
#     username: World Health Organization (WHO)
#     text: Noncommunicable diseases like rheumatic heart disease disproportionately affect women, particularly young adults, and the world’s poorest populations.
#
# To achieve #HealthForAll we must centre the most vulnerable.
#
# https://t.co/UG9knAxQlQ
#     date: Mon Jun 28 18:57:39 +0000 2021
#     hashtags: ['HealthForAll']
#     likes: 133
#     retweets: 25
#     url: None
#
# ------------------------
# ['death', 'risk']
# 1  score:  0.9999999999737973
# id: 1408027482113163265
#     username: World Health Organization (WHO)
#     text: RT @DrTedros: The #COVID19 situation in Africa is worrisome. Both the number of cases &amp; deaths are almost 40% higher than the week before.…
#     date: Thu Jun 24 11:41:26 +0000 2021
#     hashtags: ['COVID19']
#     likes: 0
#     retweets: 545
#     url: None
#
# 2  score:  0.9999999999532638
# id: 1408087054634799106
#     username: World Health Organization (WHO)
#     text: LIVE Q&amp;A on #COVID19 variants and vaccines with @doctorsoumya. #AskWHO https://t.co/RFfQvz1kmp
#     date: Thu Jun 24 15:38:09 +0000 2021
#     hashtags: ['COVID19', 'AskWHO']
#     likes: 508
#     retweets: 239
#     url: None
#
# 3  score:  0.9999999999499695
# id: 1408028717763416065
#     username: World Health Organization (WHO)
#     text: Today is Day 1 of #SelfCare Month!  💪
#
# Throughout this month we'll be sharing tips to help you protect your health - during the #COVID19 pandemic and beyond  👇
# https://t.co/0U9jroJSCx
#     date: Thu Jun 24 11:46:20 +0000 2021
#     hashtags: ['SelfCare', 'COVID19']
#     likes: 2528
#     retweets: 720
#     url: None
#
# 4  score:  0.9999999999372396
# id: 1408017215190933507
#     username: World Health Organization (WHO)
#     text: The right to health means the right to control one’s health and body – including the sexual and reproductive health rights of women and girls – without interference https://t.co/0xs5xwkoTg
#
# #HealthForAll #StandUp4HumanRights https://t.co/qfh5PQ8S2D
#     date: Thu Jun 24 11:00:38 +0000 2021
#     hashtags: ['HealthForAll', 'StandUp4HumanRights']
#     likes: 287
#     retweets: 96
#     url: https://t.co/qfh5PQ8S2D
#
# 5  score:  0.9999999999238607
# id: 1408027564321484802
#     username: World Health Organization (WHO)
#     text: RT @DrTedros: Very pleased to have spoken with Her Majesty Queen Mathilde of #Belgium about the upcoming 'Impact of violence against childr…
#     date: Thu Jun 24 11:41:45 +0000 2021
#     hashtags: ['Belgium']
#     likes: 0
#     retweets: 67
#     url: None
#
# 6  score:  0.9999999999203286
# id: 1408060159004270604
#     username: World Health Organization (WHO)
#     text: Take time each day for things you enjoy and to stay connected with those you 🤎
#
# ✅ Keep in touch with people you care about
# ✅ Think about what you can do for others
# ✅ Reach out to a trusted person or health worker if you need help
#
# 👉 https://t.co/0U9jroshdX https://t.co/yZpiyHMVgi
#     date: Thu Jun 24 13:51:17 +0000 2021
#     hashtags: []
#     likes: 509
#     retweets: 199
#     url: https://t.co/yZpiyHMVgi
#
# 7  score:  0.999999999872535
# id: 1408416636084707335
#     username: World Health Organization (WHO)
#     text: Here is why you should get vaccinated even if you have had #COVID19 👇
#     date: Fri Jun 25 13:27:47 +0000 2021
#     hashtags: ['COVID19']
#     likes: 432
#     retweets: 221
#     url: None
#
# 8  score:  0.9999999998700472
# id: 1408041924460699655
#     username: World Health Organization (WHO)
#     text: Maintaining a healthy lifestyle is vital. This means:
#
# 🍊 Eating healthily
# 🏃‍♀️ Being physically active
# 🚭 Avoiding alcohol and tobacco
# 💤 Getting enough sleep
#
# 👉 https://t.co/0U9jroJSCx
#
# #SelfCare Month
# https://t.co/crF6gAgSQW
#     date: Thu Jun 24 12:38:49 +0000 2021
#     hashtags: ['SelfCare']
#     likes: 484
#     retweets: 208
#     url: https://t.co/crF6gAgSQW
#
# 9  score:  0.999999999865741
# id: 1408411083749171202
#     username: World Health Organization (WHO)
#     text: New #SelfCare recommendations include:
# ✅ provision of 🤰 self-tests with no prescription
# ✅ Pharmacy access to emergency contraception
# ✅ Self-management of iron &amp; folic acid supplementation
# ✅ Self-monitoring of blood glucose &amp; pressure during 🤰
#
# 👉 https://t.co/dDDfj4PPEm https://t.co/6SjRf6yUBD
#     date: Fri Jun 25 13:05:44 +0000 2021
#     hashtags: ['SelfCare']
#     likes: 159
#     retweets: 28
#     url: https://t.co/6SjRf6yUBD
#
# 10  score:  0.9999999998423912
# id: 1408391491827945479
#     username: World Health Organization (WHO)
#     text: #SelfCare interventions should be complementary to #PrimaryHealthCare and not a substitute for it.
#
# Where self-care is not a ➕ choice but is prompted by fear or lack of alternatives, it can increase vulnerabilities and put people’s well-being at risk.
# https://t.co/dDDfj4PPEm https://t.co/T810wf0yJj
#     date: Fri Jun 25 11:47:52 +0000 2021
#     hashtags: ['SelfCare', 'PrimaryHealthCare']
#     likes: 123
#     retweets: 44
#     url: https://t.co/T810wf0yJj
#
# 11  score:  0.99999999981949
# id: 1408441069528924166
#     username: World Health Organization (WHO)
#     text: RT @WHO: Even after getting vaccinated against #COVID19, 𝗸𝗲𝗲𝗽 𝘁𝗮𝗸𝗶𝗻𝗴 𝗽𝗿𝗲𝗰𝗮𝘂𝘁𝗶𝗼𝗻𝘀 to protect family and friends. https://t.co/bnOGX254MB
#     date: Fri Jun 25 15:04:53 +0000 2021
#     hashtags: ['COVID19']
#     likes: 0
#     retweets: 259
#     url: https://t.co/bnOGX254MB
#
# 12  score:  0.9999999998121645
# id: 1408173679499005960
#     username: World Health Organization (WHO)
#     text: Even after getting vaccinated against #COVID19, 𝗸𝗲𝗲𝗽 𝘁𝗮𝗸𝗶𝗻𝗴 𝗽𝗿𝗲𝗰𝗮𝘂𝘁𝗶𝗼𝗻𝘀 to protect family and friends. https://t.co/bnOGX254MB
#     date: Thu Jun 24 21:22:22 +0000 2021
#     hashtags: ['COVID19']
#     likes: 528
#     retweets: 259
#     url: https://t.co/bnOGX254MB
#
# 13  score:  0.9999999997659836
# id: 1408430077654798341
#     username: World Health Organization (WHO)
#     text: #SelfCare technologies help people look after their own sexual &amp; reproductive health:
#
# 🔹Self-injectable contraceptives
# 🔹HIV &amp;hepatitis C self-testing
# 🔹Self-sampling for HPV
# 🔹🤰 self-tests
# 🔹Ovulation predictor kits for fertility management
# https://t.co/dDDfj4PPEm
#     date: Fri Jun 25 14:21:12 +0000 2021
#     hashtags: ['SelfCare']
#     likes: 92
#     retweets: 24
#     url: None
#
# 14  score:  0.9999999997327581
# id: 1408365351734284289
#     username: World Health Organization (WHO)
#     text: #SelfCare is the ability of individuals, families and communities to:
#
# ✅ promote health
# ✅ prevent diseases
# ✅ maintain health
# ✅ cope with illness and disability
#
# with or without the support of a health worker 👨‍⚕️👩‍⚕️
#
# 👉 https://t.co/dDDfj4PPEm https://t.co/5iPNdMFnL7
#     date: Fri Jun 25 10:04:00 +0000 2021
#     hashtags: ['SelfCare']
#     likes: 199
#     retweets: 88
#     url: https://t.co/5iPNdMFnL7
#
# 15  score:  0.9999999996520493
# id: 1408447246060769292
#     username: World Health Organization (WHO)
#     text: Media briefing on #COVID19 with @DrTedros https://t.co/YiMdHDIfq0
#     date: Fri Jun 25 15:29:25 +0000 2021
#     hashtags: ['COVID19']
#     likes: 585
#     retweets: 196
#     url: None
#
# 16  score:  0.9999999995218017
# id: 1408350517428953091
#     username: World Health Organization (WHO)
#     text: To celebrate #SelfCare Month WHO is releasing new guidelines on Self-Care Interventions for Health.
#
# This new 📑 recognizes how people can actively take decisions for their own health and the health of their  ♥️  ones.
# https://t.co/xzditNF4NI
#     date: Fri Jun 25 09:05:03 +0000 2021
#     hashtags: ['SelfCare']
#     likes: 451
#     retweets: 165
#     url: None
#
# 17  score:  0.9999999993468068
# id: 1408447934681731074
#     username: World Health Organization (WHO)
#     text: @DrTedros "I know that globally there is currently a lot of concern about the #COVID19 Delta variant, and WHO is concerned about it too"-@DrTedros
# https://t.co/HQFrixFVOi
#     date: Fri Jun 25 15:32:09 +0000 2021
#     hashtags: ['COVID19']
#     likes: 54
#     retweets: 16
#     url: None
#
# 18  score:  0.9999999988779282
# id: 1408448096959410181
#     username: World Health Organization (WHO)
#     text: @DrTedros "Delta [variant] is the most transmissible of the #COVID19 variants identified so far, has been identified in at least 85 countries, and is spreading rapidly among unvaccinated populations"-@DrTedros
# https://t.co/HQFrixFVOi
#     date: Fri Jun 25 15:32:48 +0000 2021
#     hashtags: ['COVID19']
#     likes: 74
#     retweets: 44
#     url: None
#
# 19  score:  0.999999998237126
# id: 1408512752264613894
#     username: World Health Organization (WHO)
#     text: RT @DrTedros: There's a lot of concern about the #COVID19 Delta variant - the most transmissible one identified so far. We must use tailore…
#     date: Fri Jun 25 19:49:43 +0000 2021
#     hashtags: ['COVID19']
#     likes: 0
#     retweets: 383
#     url: None
#
# 20  score:  0.9999999982036124
# id: 1408448204023205895
#     username: World Health Organization (WHO)
#     text: @DrTedros "As some countries ease public health and social measures, we are starting to see increases in #COVID19 transmission around the world. More cases means more hospitalizations, further stretching health workers and health systems, which increases the risk of death"-@DrTedros
#     date: Fri Jun 25 15:33:14 +0000 2021
#     hashtags: ['COVID19']
#     likes: 69
#     retweets: 33
#     url: None
#
# ------------------------
# C:\Users\Harrison\anaconda3\lib\site-packages\ipykernel_launcher.py:19: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
